# %%
Model 9: Conv2D x 3 + (batch_size = 128) + (kernel = 5) (100 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 128
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 100, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/100
# 33/33 - 30s - 909ms/step - auc_1: 0.5586 - loss: 0.5949 - val_auc_1: 0.8604 - val_loss: 0.5251
# Epoch 2/100
# 33/33 - 0s - 371us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/100
# 2024-03-31 12:52:03.868227: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:52:03.871880: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 28s - 842ms/step - auc_1: 0.8102 - loss: 0.4529 - val_auc_1: 0.9244 - val_loss: 0.3571
# Epoch 4/100
# 33/33 - 0s - 247us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/100
# 2024-03-31 12:52:31.655416: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:52:31.658373: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 29s - 888ms/step - auc_1: 0.9097 - loss: 0.3377 - val_auc_1: 0.8801 - val_loss: 0.4684
# Epoch 6/100
# 33/33 - 0s - 231us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/100
# 2024-03-31 12:53:00.961962: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:53:00.964628: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 29s - 893ms/step - auc_1: 0.9393 - loss: 0.2789 - val_auc_1: 0.9509 - val_loss: 0.4184
# Epoch 8/100
# 33/33 - 0s - 278us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/100
# 2024-03-31 12:53:30.452068: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:53:30.455176: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 29s - 882ms/step - auc_1: 0.9485 - loss: 0.2528 - val_auc_1: 0.9657 - val_loss: 0.2790
# Epoch 10/100
# 33/33 - 0s - 242us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/100
# 2024-03-31 12:53:59.586386: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:53:59.589194: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 32s - 974ms/step - auc_1: 0.9535 - loss: 0.2434 - val_auc_1: 0.9709 - val_loss: 0.4125
# Epoch 12/100
# 33/33 - 0s - 281us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/100
# 2024-03-31 12:54:31.732838: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:54:31.736129: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 33s - 993ms/step - auc_1: 0.9612 - loss: 0.2356 - val_auc_1: 0.9702 - val_loss: 0.2606
# Epoch 14/100
# 33/33 - 0s - 406us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/100
# 2024-03-31 12:55:04.509871: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:55:04.514981: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 42s - 1s/step - auc_1: 0.9601 - loss: 0.2261 - val_auc_1: 0.9771 - val_loss: 0.1711
# Epoch 16/100
# 33/33 - 0s - 464us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/100
# 2024-03-31 12:55:46.884879: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:55:46.889809: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9723 - loss: 0.1881 - val_auc_1: 0.9742 - val_loss: 0.2221
# Epoch 18/100
# 33/33 - 0s - 411us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/100
# 2024-03-31 12:56:31.865841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:56:31.869920: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9729 - loss: 0.1857 - val_auc_1: 0.9819 - val_loss: 0.1526
# Epoch 20/100
# 33/33 - 0s - 422us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/100
# 2024-03-31 12:57:15.701086: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:57:15.706420: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9741 - loss: 0.1800 - val_auc_1: 0.9858 - val_loss: 0.1759
# Epoch 22/100
# 33/33 - 0s - 627us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/100
# 2024-03-31 12:58:01.711566: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:58:01.719305: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 43s - 1s/step - auc_1: 0.9799 - loss: 0.1583 - val_auc_1: 0.9838 - val_loss: 0.1349
# Epoch 24/100
# 33/33 - 0s - 420us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/100
# 2024-03-31 12:58:44.773407: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:58:44.778796: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9798 - loss: 0.1667 - val_auc_1: 0.9857 - val_loss: 0.1889
# Epoch 26/100
# 33/33 - 0s - 656us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/100
# 2024-03-31 12:59:28.476257: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:59:28.484578: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9800 - loss: 0.1644 - val_auc_1: 0.9840 - val_loss: 0.1400
# Epoch 28/100
# 33/33 - 0s - 552us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/100
# 2024-03-31 13:00:12.439427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:00:12.446587: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9814 - loss: 0.1495 - val_auc_1: 0.9881 - val_loss: 0.1327
# Epoch 30/100
# 33/33 - 0s - 608us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/100
# 2024-03-31 13:00:55.972124: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:00:55.978200: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 43s - 1s/step - auc_1: 0.9843 - loss: 0.1377 - val_auc_1: 0.9853 - val_loss: 0.1253
# Epoch 32/100
# 33/33 - 0s - 286us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/100
# 2024-03-31 13:01:39.354619: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:01:39.357841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9834 - loss: 0.1483 - val_auc_1: 0.9846 - val_loss: 0.1393
# Epoch 34/100
# 33/33 - 0s - 327us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/100
# 2024-03-31 13:02:23.249069: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:02:23.253371: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9799 - loss: 0.1623 - val_auc_1: 0.9850 - val_loss: 0.1438
# Epoch 36/100
# 33/33 - 0s - 762us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/100
# 2024-03-31 13:03:07.071615: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:03:07.084035: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9858 - loss: 0.1309 - val_auc_1: 0.9871 - val_loss: 0.1212
# Epoch 38/100
# 33/33 - 0s - 634us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/100
# 2024-03-31 13:03:51.082273: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:03:51.089428: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9847 - loss: 0.1324 - val_auc_1: 0.9876 - val_loss: 0.1576
# Epoch 40/100
# 33/33 - 0s - 479us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/100
# 2024-03-31 13:04:35.534374: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:04:35.539967: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9867 - loss: 0.1286 - val_auc_1: 0.9887 - val_loss: 0.1175
# Epoch 42/100
# 33/33 - 0s - 704us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/100
# 2024-03-31 13:05:19.900930: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:05:19.909519: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9887 - loss: 0.1164 - val_auc_1: 0.9878 - val_loss: 0.1232
# Epoch 44/100
# 33/33 - 0s - 356us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/100
# 2024-03-31 13:06:04.349232: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:06:04.353034: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9888 - loss: 0.1160 - val_auc_1: 0.9899 - val_loss: 0.1160
# Epoch 46/100
# 33/33 - 0s - 303us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/100
# 2024-03-31 13:06:49.138612: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:06:49.142341: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9852 - loss: 0.1366 - val_auc_1: 0.9757 - val_loss: 0.1664
# Epoch 48/100
# 33/33 - 0s - 626us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/100
# 2024-03-31 13:07:34.459595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:07:34.466786: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9800 - loss: 0.1724 - val_auc_1: 0.9891 - val_loss: 0.2061
# Epoch 50/100
# 33/33 - 0s - 308us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/100
# 2024-03-31 13:08:18.754870: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:08:18.758277: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9855 - loss: 0.1344 - val_auc_1: 0.9876 - val_loss: 0.1316
# Epoch 52/100
# 33/33 - 0s - 314us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/100
# 2024-03-31 13:09:02.616576: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:09:02.620157: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9866 - loss: 0.1279 - val_auc_1: 0.9879 - val_loss: 0.1288
# Epoch 54/100
# 33/33 - 0s - 316us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/100
# 2024-03-31 13:09:47.338093: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:09:47.341701: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9882 - loss: 0.1191 - val_auc_1: 0.9879 - val_loss: 0.1367
# Epoch 56/100
# 33/33 - 0s - 295us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 2024-03-31 13:10:31.857552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:10:31.860827: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9848 - loss: 0.1414 - val_auc_1: 0.9889 - val_loss: 0.1406
# Epoch 58/100
# 33/33 - 0s - 324us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 2024-03-31 13:11:16.804646: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:11:16.808356: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 44s - 1s/step - auc_1: 0.9824 - loss: 0.1462 - val_auc_1: 0.9871 - val_loss: 0.1372
# Epoch 60/100
# 33/33 - 0s - 912us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 2024-03-31 13:12:00.816781: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:12:00.823751: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 48s - 1s/step - auc_1: 0.9886 - loss: 0.1153 - val_auc_1: 0.9884 - val_loss: 0.1215
# Epoch 62/100
# 33/33 - 0s - 654us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 2024-03-31 13:12:48.786724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:12:48.792829: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9861 - loss: 0.1290 - val_auc_1: 0.9846 - val_loss: 0.1420
# Epoch 64/100
# 33/33 - 0s - 595us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 2024-03-31 13:13:33.878760: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:13:33.885908: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9861 - loss: 0.1242 - val_auc_1: 0.9897 - val_loss: 0.1506
# Epoch 66/100
# 33/33 - 0s - 294us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 2024-03-31 13:14:18.642841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:14:18.646384: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9872 - loss: 0.1194 - val_auc_1: 0.9849 - val_loss: 0.1343
# Epoch 68/100
# 33/33 - 0s - 338us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 2024-03-31 13:15:03.756468: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:15:03.760523: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 45s - 1s/step - auc_1: 0.9862 - loss: 0.1310 - val_auc_1: 0.9872 - val_loss: 0.1622
# Epoch 70/100
# 33/33 - 0s - 286us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 2024-03-31 13:15:48.627555: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:15:48.630848: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9891 - loss: 0.1185 - val_auc_1: 0.9856 - val_loss: 0.1627
# Epoch 72/100
# 33/33 - 0s - 299us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 2024-03-31 13:16:34.819815: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:16:34.823345: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9887 - loss: 0.1164 - val_auc_1: 0.9843 - val_loss: 0.1418
# Epoch 74/100
# 33/33 - 0s - 684us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 2024-03-31 13:17:21.170698: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:17:21.178475: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 49s - 1s/step - auc_1: 0.9892 - loss: 0.1191 - val_auc_1: 0.9841 - val_loss: 0.1390
# Epoch 76/100
# 33/33 - 0s - 584us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 2024-03-31 13:18:10.354663: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:18:10.359744: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 48s - 1s/step - auc_1: 0.9880 - loss: 0.1147 - val_auc_1: 0.9874 - val_loss: 0.1416
# Epoch 78/100
# 33/33 - 0s - 508us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 2024-03-31 13:18:58.326769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:18:58.333084: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 47s - 1s/step - auc_1: 0.9901 - loss: 0.1116 - val_auc_1: 0.9868 - val_loss: 0.1335
# Epoch 80/100
# 33/33 - 0s - 601us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 2024-03-31 13:19:45.608642: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:19:45.616842: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9896 - loss: 0.1120 - val_auc_1: 0.9854 - val_loss: 0.1355
# Epoch 82/100
# 33/33 - 0s - 425us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 2024-03-31 13:20:31.345618: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:20:31.351430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9874 - loss: 0.1205 - val_auc_1: 0.9877 - val_loss: 0.1513
# Epoch 84/100
# 33/33 - 0s - 794us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 2024-03-31 13:21:17.747628: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:21:17.760815: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9898 - loss: 0.1049 - val_auc_1: 0.9869 - val_loss: 0.1368
# Epoch 86/100
# 33/33 - 0s - 607us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 2024-03-31 13:22:03.925883: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:22:03.933652: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9895 - loss: 0.1096 - val_auc_1: 0.9876 - val_loss: 0.1268
# Epoch 88/100
# 33/33 - 0s - 413us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 2024-03-31 13:22:49.597713: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:22:49.603034: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9911 - loss: 0.1021 - val_auc_1: 0.9879 - val_loss: 0.1273
# Epoch 90/100
# 33/33 - 0s - 489us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 2024-03-31 13:23:35.407420: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:23:35.410861: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9912 - loss: 0.1023 - val_auc_1: 0.9859 - val_loss: 0.1430
# Epoch 92/100
# 33/33 - 0s - 597us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 2024-03-31 13:24:21.591016: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:24:21.599717: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 49s - 1s/step - auc_1: 0.9900 - loss: 0.1073 - val_auc_1: 0.9871 - val_loss: 0.1549
# Epoch 94/100
# 33/33 - 0s - 359us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 2024-03-31 13:25:10.902881: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:25:10.907558: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9927 - loss: 0.0945 - val_auc_1: 0.9889 - val_loss: 0.1246
# Epoch 96/100
# 33/33 - 0s - 337us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 2024-03-31 13:25:57.278223: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:25:57.282087: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 46s - 1s/step - auc_1: 0.9930 - loss: 0.0920 - val_auc_1: 0.9891 - val_loss: 0.1244
# Epoch 98/100
# 33/33 - 0s - 280us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 2024-03-31 13:26:42.839411: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:26:42.842782: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 33/33 - 48s - 1s/step - auc_1: 0.9891 - loss: 0.1321 - val_auc_1: 0.9752 - val_loss: 0.1685
# Epoch 100/100
# 33/33 - 0s - 316us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 13:27:30.701803: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:27:30.705462: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 521ms/step
# [Summary Statistics]
# Accuracy = 90.75% | Precision = 91.53% | Recall = 96.25% | Specificity = 75.85% | F1 Score = 93.83%

# %% [markdown]
# Model 10: Conv2D x 3 + (batch_size = 32) + (kernel = 7) (100 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 100, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/100
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 129/129 - 38s - 293ms/step - auc_2: 0.6753 - loss: 0.5350 - val_auc_2: 0.9143 - val_loss: 0.3413
# Epoch 2/100
# 129/129 - 0s - 131us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/100
# 2024-03-31 13:44:51.973273: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 13:44:51.978598: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 41s - 314ms/step - auc_2: 0.9207 - loss: 0.3111 - val_auc_2: 0.9507 - val_loss: 0.2679
# Epoch 4/100
# 129/129 - 0s - 158us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/100
# 2024-03-31 13:45:32.557836: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:45:32.566908: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 333ms/step - auc_2: 0.9515 - loss: 0.2497 - val_auc_2: 0.9633 - val_loss: 0.2707
# Epoch 6/100
# 129/129 - 0s - 139us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/100
# 2024-03-31 13:46:15.537587: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:46:15.544812: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 339ms/step - auc_2: 0.9563 - loss: 0.2343 - val_auc_2: 0.9699 - val_loss: 0.2303
# Epoch 8/100
# 129/129 - 0s - 146us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/100
# 2024-03-31 13:46:59.295099: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:46:59.303350: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 345ms/step - auc_2: 0.9629 - loss: 0.2151 - val_auc_2: 0.9731 - val_loss: 0.1826
# Epoch 10/100
# 129/129 - 0s - 169us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/100
# 2024-03-31 13:47:43.838658: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:47:43.847759: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 348ms/step - auc_2: 0.9717 - loss: 0.1910 - val_auc_2: 0.9742 - val_loss: 0.1839
# Epoch 12/100
# 129/129 - 0s - 87us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/100
# 2024-03-31 13:48:28.723888: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:48:28.727769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 349ms/step - auc_2: 0.9626 - loss: 0.2187 - val_auc_2: 0.9797 - val_loss: 0.2615
# Epoch 14/100
# 129/129 - 0s - 236us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/100
# 2024-03-31 13:49:13.828780: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:49:13.842918: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 370ms/step - auc_2: 0.9697 - loss: 0.1981 - val_auc_2: 0.9728 - val_loss: 0.2148
# Epoch 16/100
# 129/129 - 0s - 83us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/100
# 2024-03-31 13:50:01.652965: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:50:01.656736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 364ms/step - auc_2: 0.9748 - loss: 0.1816 - val_auc_2: 0.9813 - val_loss: 0.2044
# Epoch 18/100
# 129/129 - 0s - 112us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/100
# 2024-03-31 13:50:48.565686: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:50:48.570065: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 51s - 393ms/step - auc_2: 0.9772 - loss: 0.1701 - val_auc_2: 0.9800 - val_loss: 0.1957
# Epoch 20/100
# 129/129 - 0s - 143us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/100
# 2024-03-31 13:51:39.253126: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:51:39.259855: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 348ms/step - auc_2: 0.9780 - loss: 0.1661 - val_auc_2: 0.9782 - val_loss: 0.1647
# Epoch 22/100
# 129/129 - 0s - 74us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/100
# 2024-03-31 13:52:24.145492: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:52:24.148893: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 362ms/step - auc_2: 0.9769 - loss: 0.1723 - val_auc_2: 0.9802 - val_loss: 0.1986
# Epoch 24/100
# 129/129 - 0s - 99us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/100
# 2024-03-31 13:53:10.798751: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:53:10.802150: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 79s - 614ms/step - auc_2: 0.9799 - loss: 0.1590 - val_auc_2: 0.9805 - val_loss: 0.1632
# Epoch 26/100
# 129/129 - 0s - 84us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/100
# 2024-03-31 13:54:29.961164: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:54:29.964819: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 350ms/step - auc_2: 0.9784 - loss: 0.1626 - val_auc_2: 0.9850 - val_loss: 0.1815
# Epoch 28/100
# 129/129 - 0s - 81us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/100
# 2024-03-31 13:55:15.116617: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:55:15.120330: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 348ms/step - auc_2: 0.9782 - loss: 0.1632 - val_auc_2: 0.9837 - val_loss: 0.1476
# Epoch 30/100
# 129/129 - 0s - 186us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/100
# 2024-03-31 13:55:59.979524: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:55:59.987472: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_2: 0.9794 - loss: 0.1617 - val_auc_2: 0.9864 - val_loss: 0.1357
# Epoch 32/100
# 129/129 - 0s - 108us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/100
# 2024-03-31 13:56:43.843102: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:56:43.848838: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 337ms/step - auc_2: 0.9807 - loss: 0.1550 - val_auc_2: 0.9825 - val_loss: 0.1479
# Epoch 34/100
# 129/129 - 0s - 75us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/100
# 2024-03-31 13:57:27.360801: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:57:27.364067: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 342ms/step - auc_2: 0.9838 - loss: 0.1423 - val_auc_2: 0.9834 - val_loss: 0.1450
# Epoch 36/100
# 129/129 - 0s - 135us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/100
# 2024-03-31 13:58:11.489071: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:58:11.495184: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_2: 0.9811 - loss: 0.1519 - val_auc_2: 0.9835 - val_loss: 0.1431
# Epoch 38/100
# 129/129 - 0s - 107us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/100
# 2024-03-31 13:58:55.793238: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:58:55.797335: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_2: 0.9832 - loss: 0.1412 - val_auc_2: 0.9837 - val_loss: 0.1338
# Epoch 40/100
# 129/129 - 0s - 171us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/100
# 2024-03-31 13:59:39.618216: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:59:39.626693: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_2: 0.9842 - loss: 0.1404 - val_auc_2: 0.9825 - val_loss: 0.2065
# Epoch 42/100
# 129/129 - 0s - 80us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/100
# 2024-03-31 14:00:23.275039: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:00:23.278484: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_2: 0.9822 - loss: 0.1455 - val_auc_2: 0.9823 - val_loss: 0.1459
# Epoch 44/100
# 129/129 - 0s - 129us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/100
# 2024-03-31 14:01:07.202122: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:01:07.207380: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_2: 0.9828 - loss: 0.1470 - val_auc_2: 0.9807 - val_loss: 0.1484
# Epoch 46/100
# 129/129 - 0s - 147us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/100
# 2024-03-31 14:01:50.795699: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:01:50.802662: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_2: 0.9850 - loss: 0.1371 - val_auc_2: 0.9827 - val_loss: 0.1593
# Epoch 48/100
# 129/129 - 0s - 83us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/100
# 2024-03-31 14:02:34.871303: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:02:34.874779: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_2: 0.9852 - loss: 0.1336 - val_auc_2: 0.9844 - val_loss: 0.1349
# Epoch 50/100
# 129/129 - 0s - 173us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/100
# 2024-03-31 14:03:19.117318: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:03:19.125602: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 342ms/step - auc_2: 0.9839 - loss: 0.1419 - val_auc_2: 0.9850 - val_loss: 0.1313
# Epoch 52/100
# 129/129 - 0s - 175us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/100
# 2024-03-31 14:04:03.219835: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:04:03.226357: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_2: 0.9829 - loss: 0.1450 - val_auc_2: 0.9845 - val_loss: 0.1351
# Epoch 54/100
# 129/129 - 0s - 81us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/100
# 2024-03-31 14:04:48.051974: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:04:48.055789: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_2: 0.9855 - loss: 0.1370 - val_auc_2: 0.9855 - val_loss: 0.1340
# Epoch 56/100
# 129/129 - 0s - 75us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 2024-03-31 14:05:32.867400: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:05:32.870590: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_2: 0.9857 - loss: 0.1343 - val_auc_2: 0.9845 - val_loss: 0.1419
# Epoch 58/100
# 129/129 - 0s - 81us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 2024-03-31 14:06:16.723433: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:06:16.726953: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_2: 0.9859 - loss: 0.1320 - val_auc_2: 0.9852 - val_loss: 0.1316
# Epoch 60/100
# 129/129 - 0s - 117us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 2024-03-31 14:07:01.560864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:07:01.568244: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 344ms/step - auc_2: 0.9874 - loss: 0.1266 - val_auc_2: 0.9847 - val_loss: 0.1855
# Epoch 62/100
# 129/129 - 0s - 159us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 2024-03-31 14:07:45.897496: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:07:45.905941: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 353ms/step - auc_2: 0.9854 - loss: 0.1349 - val_auc_2: 0.9819 - val_loss: 0.1562
# Epoch 64/100
# 129/129 - 0s - 84us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 2024-03-31 14:08:31.459639: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:08:31.463408: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 339ms/step - auc_2: 0.9873 - loss: 0.1212 - val_auc_2: 0.9836 - val_loss: 0.1383
# Epoch 66/100
# 129/129 - 0s - 82us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 2024-03-31 14:09:15.181306: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:09:15.185010: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_2: 0.9864 - loss: 0.1300 - val_auc_2: 0.9839 - val_loss: 0.1634
# Epoch 68/100
# 129/129 - 0s - 68us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 2024-03-31 14:09:59.175132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:09:59.178218: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_2: 0.9881 - loss: 0.1196 - val_auc_2: 0.9825 - val_loss: 0.2156
# Epoch 70/100
# 129/129 - 0s - 79us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 2024-03-31 14:10:43.222543: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:10:43.226260: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 344ms/step - auc_2: 0.9876 - loss: 0.1188 - val_auc_2: 0.9832 - val_loss: 0.1351
# Epoch 72/100
# 129/129 - 0s - 188us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 2024-03-31 14:11:27.600004: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:11:27.611205: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 342ms/step - auc_2: 0.9866 - loss: 0.1259 - val_auc_2: 0.9842 - val_loss: 0.1409
# Epoch 74/100
# 129/129 - 0s - 136us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 2024-03-31 14:12:11.812920: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:12:11.818871: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 346ms/step - auc_2: 0.9893 - loss: 0.1145 - val_auc_2: 0.9844 - val_loss: 0.1711
# Epoch 76/100
# 129/129 - 0s - 128us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 2024-03-31 14:12:56.513457: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:12:56.519956: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 339ms/step - auc_2: 0.9886 - loss: 0.1170 - val_auc_2: 0.9837 - val_loss: 0.1478
# Epoch 78/100
# 129/129 - 0s - 66us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 2024-03-31 14:13:40.327645: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:13:40.330661: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_2: 0.9902 - loss: 0.1091 - val_auc_2: 0.9873 - val_loss: 0.1390
# Epoch 80/100
# 129/129 - 0s - 66us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 2024-03-31 14:14:24.570733: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:14:24.573774: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 336ms/step - auc_2: 0.9913 - loss: 0.1042 - val_auc_2: 0.9880 - val_loss: 0.1961
# Epoch 82/100
# 129/129 - 0s - 146us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 2024-03-31 14:15:07.867911: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:15:07.874193: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 345ms/step - auc_2: 0.9900 - loss: 0.1116 - val_auc_2: 0.9890 - val_loss: 0.1216
# Epoch 84/100
# 129/129 - 0s - 74us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 2024-03-31 14:15:52.443256: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:15:52.446869: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 345ms/step - auc_2: 0.9895 - loss: 0.1146 - val_auc_2: 0.9882 - val_loss: 0.1215
# Epoch 86/100
# 129/129 - 0s - 68us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 2024-03-31 14:16:36.974123: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:16:36.977197: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_2: 0.9909 - loss: 0.1040 - val_auc_2: 0.9837 - val_loss: 0.1365
# Epoch 88/100
# 129/129 - 0s - 65us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 2024-03-31 14:17:21.739397: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:17:21.742398: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 364ms/step - auc_2: 0.9894 - loss: 0.1156 - val_auc_2: 0.9849 - val_loss: 0.1358
# Epoch 90/100
# 129/129 - 0s - 83us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 2024-03-31 14:18:08.712785: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:18:08.716539: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_2: 0.9889 - loss: 0.1178 - val_auc_2: 0.9903 - val_loss: 0.1416
# Epoch 92/100
# 129/129 - 0s - 69us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 2024-03-31 14:18:52.968544: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:18:52.971711: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 344ms/step - auc_2: 0.9890 - loss: 0.1111 - val_auc_2: 0.9859 - val_loss: 0.1311
# Epoch 94/100
# 129/129 - 0s - 76us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 2024-03-31 14:19:37.387189: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:19:37.390511: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 35s - 268ms/step - auc_2: 0.9903 - loss: 0.1069 - val_auc_2: 0.9844 - val_loss: 0.1258
# Epoch 96/100
# 129/129 - 0s - 59us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 2024-03-31 14:20:11.994391: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:20:11.997038: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 32s - 248ms/step - auc_2: 0.9904 - loss: 0.1061 - val_auc_2: 0.9846 - val_loss: 0.1434
# Epoch 98/100
# 129/129 - 0s - 62us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 2024-03-31 14:20:43.990986: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:20:43.993669: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 32s - 244ms/step - auc_2: 0.9895 - loss: 0.1115 - val_auc_2: 0.9876 - val_loss: 0.1216
# Epoch 100/100
# 129/129 - 0s - 62us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 14:21:15.524211: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:21:15.527018: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step
# [Summary Statistics]
# Accuracy = 91.78% | Precision = 91.28% | Recall = 98.12% | Specificity = 74.58% | F1 Score = 94.58%

# %%
Model 11: Conv2D x 3 + (batch_size = 64) + (kernel = 7) (100 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 64
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=7, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 100, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/100
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 65/65 - 29s - 444ms/step - auc_3: 0.6405 - loss: 0.5571 - val_auc_3: 0.8947 - val_loss: 0.3856
# Epoch 2/100
# 65/65 - 0s - 201us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/100
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 14:31:31.197296: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:31:31.200950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 36s - 561ms/step - auc_3: 0.9043 - loss: 0.3437 - val_auc_3: 0.9236 - val_loss: 0.3508
# Epoch 4/100
# 65/65 - 0s - 138us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/100
# 2024-03-31 14:32:07.704677: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:32:07.707953: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 41s - 625ms/step - auc_3: 0.9228 - loss: 0.3059 - val_auc_3: 0.9429 - val_loss: 0.2949
# Epoch 6/100
# 65/65 - 0s - 156us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/100
# 2024-03-31 14:32:48.357778: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:32:48.361178: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 671ms/step - auc_3: 0.9459 - loss: 0.2590 - val_auc_3: 0.9591 - val_loss: 0.2548
# Epoch 8/100
# 65/65 - 0s - 173us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/100
# 2024-03-31 14:33:31.967294: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:33:31.971636: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 668ms/step - auc_3: 0.9514 - loss: 0.2487 - val_auc_3: 0.9601 - val_loss: 0.2590
# Epoch 10/100
# 65/65 - 0s - 363us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/100
# 2024-03-31 14:34:15.395969: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:34:15.401458: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 675ms/step - auc_3: 0.9419 - loss: 0.2752 - val_auc_3: 0.9660 - val_loss: 0.2124
# Epoch 12/100
# 65/65 - 0s - 235us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/100
# 2024-03-31 14:34:59.282414: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:34:59.287755: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 673ms/step - auc_3: 0.9644 - loss: 0.2087 - val_auc_3: 0.9686 - val_loss: 0.2124
# Epoch 14/100
# 65/65 - 0s - 270us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/100
# 2024-03-31 14:35:43.043428: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:35:43.050026: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 691ms/step - auc_3: 0.9697 - loss: 0.1934 - val_auc_3: 0.9701 - val_loss: 0.2501
# Epoch 16/100
# 65/65 - 0s - 154us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/100
# 2024-03-31 14:36:27.962396: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:36:27.965974: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 746ms/step - auc_3: 0.9674 - loss: 0.2070 - val_auc_3: 0.9704 - val_loss: 0.1961
# Epoch 18/100
# 65/65 - 0s - 324us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/100
# 2024-03-31 14:37:16.439223: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:37:16.445393: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 777ms/step - auc_3: 0.9690 - loss: 0.1955 - val_auc_3: 0.9705 - val_loss: 0.2516
# Epoch 20/100
# 65/65 - 0s - 182us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/100
# 2024-03-31 14:38:06.954688: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:38:06.958519: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 55s - 847ms/step - auc_3: 0.9742 - loss: 0.1817 - val_auc_3: 0.9730 - val_loss: 0.2164
# Epoch 22/100
# 65/65 - 0s - 459us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/100
# 2024-03-31 14:39:02.036287: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:39:02.045106: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 740ms/step - auc_3: 0.9745 - loss: 0.1793 - val_auc_3: 0.9736 - val_loss: 0.1816
# Epoch 24/100
# 65/65 - 0s - 177us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/100
# 2024-03-31 14:39:50.143927: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:39:50.147622: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 740ms/step - auc_3: 0.9747 - loss: 0.1808 - val_auc_3: 0.9709 - val_loss: 0.1888
# Epoch 26/100
# 65/65 - 0s - 292us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/100
# 2024-03-31 14:40:38.281540: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:40:38.288413: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 47s - 729ms/step - auc_3: 0.9736 - loss: 0.1872 - val_auc_3: 0.9748 - val_loss: 0.2718
# Epoch 28/100
# 65/65 - 0s - 184us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/100
# 2024-03-31 14:41:25.676732: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:41:25.680952: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 738ms/step - auc_3: 0.9749 - loss: 0.1835 - val_auc_3: 0.9732 - val_loss: 0.1789
# Epoch 30/100
# 65/65 - 0s - 169us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/100
# 2024-03-31 14:42:13.681714: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:42:13.685695: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 743ms/step - auc_3: 0.9770 - loss: 0.1685 - val_auc_3: 0.9753 - val_loss: 0.2075
# Epoch 32/100
# 65/65 - 0s - 168us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/100
# 2024-03-31 14:43:01.976710: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:43:01.980550: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 735ms/step - auc_3: 0.9698 - loss: 0.1917 - val_auc_3: 0.9765 - val_loss: 0.1858
# Epoch 34/100
# 65/65 - 0s - 375us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/100
# 2024-03-31 14:43:49.759321: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:43:49.767945: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 745ms/step - auc_3: 0.9774 - loss: 0.1708 - val_auc_3: 0.9764 - val_loss: 0.1809
# Epoch 36/100
# 65/65 - 0s - 288us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/100
# 2024-03-31 14:44:38.203538: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:44:38.211380: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 740ms/step - auc_3: 0.9766 - loss: 0.1682 - val_auc_3: 0.9797 - val_loss: 0.1713
# Epoch 38/100
# 65/65 - 0s - 175us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/100
# 2024-03-31 14:45:26.319311: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:45:26.323189: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 752ms/step - auc_3: 0.9818 - loss: 0.1510 - val_auc_3: 0.9831 - val_loss: 0.1586
# Epoch 40/100
# 65/65 - 0s - 181us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/100
# 2024-03-31 14:46:15.207602: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:46:15.211516: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 743ms/step - auc_3: 0.9829 - loss: 0.1462 - val_auc_3: 0.9768 - val_loss: 0.1938
# Epoch 42/100
# 65/65 - 0s - 153us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/100
# 2024-03-31 14:47:03.496352: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:47:03.499831: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 743ms/step - auc_3: 0.9805 - loss: 0.1563 - val_auc_3: 0.9798 - val_loss: 0.1646
# Epoch 44/100
# 65/65 - 0s - 141us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/100
# 2024-03-31 14:47:51.801257: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:47:51.804429: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 752ms/step - auc_3: 0.9809 - loss: 0.1547 - val_auc_3: 0.9799 - val_loss: 0.1467
# Epoch 46/100
# 65/65 - 0s - 148us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/100
# 2024-03-31 14:48:40.664118: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:48:40.667525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 754ms/step - auc_3: 0.9837 - loss: 0.1421 - val_auc_3: 0.9773 - val_loss: 0.1659
# Epoch 48/100
# 65/65 - 0s - 148us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/100
# 2024-03-31 14:49:29.662426: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:49:29.665966: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 757ms/step - auc_3: 0.9824 - loss: 0.1516 - val_auc_3: 0.9801 - val_loss: 0.1794
# Epoch 50/100
# 65/65 - 0s - 187us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/100
# 2024-03-31 14:50:18.904813: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:50:18.908635: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 752ms/step - auc_3: 0.9815 - loss: 0.1519 - val_auc_3: 0.9814 - val_loss: 0.1539
# Epoch 52/100
# 65/65 - 0s - 153us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/100
# 2024-03-31 14:51:07.833012: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:51:07.836716: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 745ms/step - auc_3: 0.9797 - loss: 0.1614 - val_auc_3: 0.9805 - val_loss: 0.1645
# Epoch 54/100
# 65/65 - 0s - 162us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/100
# 2024-03-31 14:51:56.244966: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:51:56.248692: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 754ms/step - auc_3: 0.9818 - loss: 0.1519 - val_auc_3: 0.9803 - val_loss: 0.1613
# Epoch 56/100
# 65/65 - 0s - 156us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 2024-03-31 14:52:45.259666: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:52:45.263344: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 49s - 757ms/step - auc_3: 0.9812 - loss: 0.1568 - val_auc_3: 0.9793 - val_loss: 0.1879
# Epoch 58/100
# 65/65 - 0s - 335us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 2024-03-31 14:53:34.478802: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:53:34.486854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 775ms/step - auc_3: 0.9843 - loss: 0.1395 - val_auc_3: 0.9778 - val_loss: 0.1736
# Epoch 60/100
# 65/65 - 0s - 447us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 2024-03-31 14:54:24.912340: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:54:24.926349: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 767ms/step - auc_3: 0.9847 - loss: 0.1396 - val_auc_3: 0.9865 - val_loss: 0.1717
# Epoch 62/100
# 65/65 - 0s - 212us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 2024-03-31 14:55:14.802008: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:55:14.807153: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 770ms/step - auc_3: 0.9848 - loss: 0.1354 - val_auc_3: 0.9836 - val_loss: 0.1549
# Epoch 64/100
# 65/65 - 0s - 190us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 2024-03-31 14:56:04.848169: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:56:04.852360: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 766ms/step - auc_3: 0.9831 - loss: 0.1355 - val_auc_3: 0.9817 - val_loss: 0.1444
# Epoch 66/100
# 65/65 - 0s - 255us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 2024-03-31 14:56:54.640381: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:56:54.647564: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 767ms/step - auc_3: 0.9858 - loss: 0.1304 - val_auc_3: 0.9826 - val_loss: 0.1414
# Epoch 68/100
# 65/65 - 0s - 286us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 2024-03-31 14:57:44.536551: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:57:44.542234: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 765ms/step - auc_3: 0.9866 - loss: 0.1295 - val_auc_3: 0.9793 - val_loss: 0.1799
# Epoch 70/100
# 65/65 - 0s - 201us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 2024-03-31 14:58:34.258455: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:58:34.263298: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 766ms/step - auc_3: 0.9864 - loss: 0.1301 - val_auc_3: 0.9822 - val_loss: 0.1908
# Epoch 72/100
# 65/65 - 0s - 188us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 2024-03-31 14:59:24.091868: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:59:24.096189: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 53s - 809ms/step - auc_3: 0.9868 - loss: 0.1280 - val_auc_3: 0.9782 - val_loss: 0.1733
# Epoch 74/100
# 65/65 - 0s - 211us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 2024-03-31 15:00:16.711918: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:00:16.716717: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 54s - 833ms/step - auc_3: 0.9860 - loss: 0.1318 - val_auc_3: 0.9840 - val_loss: 0.1388
# Epoch 76/100
# 65/65 - 0s - 226us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 2024-03-31 15:01:10.907888: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:01:10.913172: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 51s - 781ms/step - auc_3: 0.9856 - loss: 0.1325 - val_auc_3: 0.9828 - val_loss: 0.1479
# Epoch 78/100
# 65/65 - 0s - 141us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 2024-03-31 15:02:01.688112: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:02:01.691539: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 768ms/step - auc_3: 0.9852 - loss: 0.1349 - val_auc_3: 0.9826 - val_loss: 0.1561
# Epoch 80/100
# 65/65 - 0s - 150us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 2024-03-31 15:02:51.647584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:02:51.651177: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 770ms/step - auc_3: 0.9866 - loss: 0.1283 - val_auc_3: 0.9849 - val_loss: 0.1341
# Epoch 82/100
# 65/65 - 0s - 169us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 2024-03-31 15:03:41.741319: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:03:41.745789: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 776ms/step - auc_3: 0.9845 - loss: 0.1436 - val_auc_3: 0.9877 - val_loss: 0.1421
# Epoch 84/100
# 65/65 - 0s - 187us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 2024-03-31 15:04:32.168048: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:04:32.172311: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 51s - 783ms/step - auc_3: 0.9878 - loss: 0.1248 - val_auc_3: 0.9862 - val_loss: 0.1471
# Epoch 86/100
# 65/65 - 0s - 226us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 2024-03-31 15:05:23.100459: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:05:23.105021: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 773ms/step - auc_3: 0.9876 - loss: 0.1262 - val_auc_3: 0.9833 - val_loss: 0.1542
# Epoch 88/100
# 65/65 - 0s - 177us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 2024-03-31 15:06:13.343939: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:06:13.348001: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 737ms/step - auc_3: 0.9878 - loss: 0.1211 - val_auc_3: 0.9826 - val_loss: 0.1461
# Epoch 90/100
# 65/65 - 0s - 295us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 2024-03-31 15:07:01.245608: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:07:01.254686: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 47s - 720ms/step - auc_3: 0.9883 - loss: 0.1250 - val_auc_3: 0.9868 - val_loss: 0.1372
# Epoch 92/100
# 65/65 - 0s - 163us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 2024-03-31 15:07:48.093040: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:07:48.096705: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 765ms/step - auc_3: 0.9879 - loss: 0.1241 - val_auc_3: 0.9879 - val_loss: 0.1409
# Epoch 94/100
# 65/65 - 0s - 337us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 2024-03-31 15:08:37.822911: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:08:37.829846: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 47s - 728ms/step - auc_3: 0.9896 - loss: 0.1129 - val_auc_3: 0.9814 - val_loss: 0.1423
# Epoch 96/100
# 65/65 - 0s - 267us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 2024-03-31 15:09:25.168701: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:09:25.173963: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 51s - 777ms/step - auc_3: 0.9892 - loss: 0.1149 - val_auc_3: 0.9898 - val_loss: 0.1327
# Epoch 98/100
# 65/65 - 0s - 166us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 2024-03-31 15:10:15.704430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:10:15.707977: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 50s - 763ms/step - auc_3: 0.9865 - loss: 0.1247 - val_auc_3: 0.9856 - val_loss: 0.1328
# Epoch 100/100
# 65/65 - 0s - 189us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 15:11:05.317960: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:11:05.322193: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step
# [Summary Statistics]
# Accuracy = 91.67% | Precision = 92.12% | Recall = 96.88% | Specificity = 77.54% | F1 Score = 94.44%
