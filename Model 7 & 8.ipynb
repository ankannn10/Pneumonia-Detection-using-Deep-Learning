# %% [markdown]
# Model 7(a): Conv2D + (batch_size = 64) + (kernel = 5) + 128 dense units (100 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 64
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn model 
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 100, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/100
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 65/65 - 44s - 670ms/step - auc: 0.6543 - loss: 0.5496 - val_auc: 0.9266 - val_loss: 0.4560
# Epoch 2/100
# 65/65 - 0s - 316us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/100
# 2024-03-31 12:55:43.019115: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 12:55:43.026846: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 655ms/step - auc: 0.9320 - loss: 0.2939 - val_auc: 0.9521 - val_loss: 0.5046
# Epoch 4/100
# 65/65 - 0s - 526us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/100
# 2024-03-31 12:56:25.600060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:56:25.616196: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 647ms/step - auc: 0.9461 - loss: 0.2632 - val_auc: 0.9648 - val_loss: 0.2752
# Epoch 6/100
# 65/65 - 0s - 424us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/100
# 2024-03-31 12:57:07.699067: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:57:07.711715: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 693ms/step - auc: 0.9575 - loss: 0.2287 - val_auc: 0.9679 - val_loss: 0.2399
# Epoch 8/100
# 65/65 - 0s - 342us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/100
# 2024-03-31 12:57:52.783021: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:57:52.791673: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 41s - 638ms/step - auc: 0.9615 - loss: 0.2211 - val_auc: 0.9767 - val_loss: 0.1933
# Epoch 10/100
# 65/65 - 0s - 303us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/100
# 2024-03-31 12:58:34.301434: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:58:34.310999: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 643ms/step - auc: 0.9674 - loss: 0.2098 - val_auc: 0.9752 - val_loss: 0.1823
# Epoch 12/100
# 65/65 - 0s - 1ms/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/100
# 2024-03-31 12:59:16.114659: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:59:16.126758: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 41s - 634ms/step - auc: 0.9733 - loss: 0.1800 - val_auc: 0.9778 - val_loss: 0.2235
# Epoch 14/100
# 65/65 - 0s - 136us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/100
# 2024-03-31 12:59:57.417895: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 12:59:57.420814: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 41s - 637ms/step - auc: 0.9776 - loss: 0.1680 - val_auc: 0.9779 - val_loss: 0.1634
# Epoch 16/100
# 65/65 - 0s - 340us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/100
# 2024-03-31 13:00:38.822841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:00:38.832543: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 644ms/step - auc: 0.9749 - loss: 0.1841 - val_auc: 0.9776 - val_loss: 0.1569
# Epoch 18/100
# 65/65 - 0s - 159us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/100
# 2024-03-31 13:01:20.721993: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:01:20.725482: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 642ms/step - auc: 0.9778 - loss: 0.1657 - val_auc: 0.9771 - val_loss: 0.2262
# Epoch 20/100
# 65/65 - 0s - 142us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/100
# 2024-03-31 13:02:02.469803: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:02:02.472991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 652ms/step - auc: 0.9807 - loss: 0.1561 - val_auc: 0.9843 - val_loss: 0.1429
# Epoch 22/100
# 65/65 - 0s - 220us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/100
# 2024-03-31 13:02:44.891215: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:02:44.896123: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 41s - 633ms/step - auc: 0.9800 - loss: 0.1580 - val_auc: 0.9835 - val_loss: 0.1449
# Epoch 24/100
# 65/65 - 0s - 124us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/100
# 2024-03-31 13:03:26.043371: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:03:26.046084: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 659ms/step - auc: 0.9812 - loss: 0.1562 - val_auc: 0.9847 - val_loss: 0.1409
# Epoch 26/100
# 65/65 - 0s - 317us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/100
# 2024-03-31 13:04:08.884056: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:04:08.891388: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 646ms/step - auc: 0.9828 - loss: 0.1493 - val_auc: 0.9842 - val_loss: 0.2413
# Epoch 28/100
# 65/65 - 0s - 131us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/100
# 2024-03-31 13:04:50.900563: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:04:50.903615: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 644ms/step - auc: 0.9816 - loss: 0.1563 - val_auc: 0.9818 - val_loss: 0.1529
# Epoch 30/100
# 65/65 - 0s - 246us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/100
# 2024-03-31 13:05:32.808539: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:05:32.814804: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 648ms/step - auc: 0.9835 - loss: 0.1405 - val_auc: 0.9843 - val_loss: 0.1884
# Epoch 32/100
# 65/65 - 0s - 378us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/100
# 2024-03-31 13:06:14.949834: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:06:14.954369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 662ms/step - auc: 0.9826 - loss: 0.1463 - val_auc: 0.9769 - val_loss: 0.1894
# Epoch 34/100
# 65/65 - 0s - 139us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/100
# 2024-03-31 13:06:57.997105: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:06:58.000433: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 650ms/step - auc: 0.9834 - loss: 0.1446 - val_auc: 0.9837 - val_loss: 0.1519
# Epoch 36/100
# 65/65 - 0s - 132us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/100
# 2024-03-31 13:07:40.270318: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:07:40.273178: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 665ms/step - auc: 0.9810 - loss: 0.1493 - val_auc: 0.9852 - val_loss: 0.1356
# Epoch 38/100
# 65/65 - 0s - 148us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/100
# 2024-03-31 13:08:23.525084: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:08:23.528472: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 659ms/step - auc: 0.9872 - loss: 0.1260 - val_auc: 0.9843 - val_loss: 0.1351
# Epoch 40/100
# 65/65 - 0s - 132us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/100
# 2024-03-31 13:09:06.346293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:09:06.349274: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 658ms/step - auc: 0.9861 - loss: 0.1262 - val_auc: 0.9856 - val_loss: 0.1957
# Epoch 42/100
# 65/65 - 0s - 129us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/100
# 2024-03-31 13:09:49.146390: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:09:49.149388: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 668ms/step - auc: 0.9830 - loss: 0.1422 - val_auc: 0.9838 - val_loss: 0.1353
# Epoch 44/100
# 65/65 - 0s - 133us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/100
# 2024-03-31 13:10:32.581703: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:10:32.584733: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 663ms/step - auc: 0.9872 - loss: 0.1254 - val_auc: 0.9849 - val_loss: 0.1295
# Epoch 46/100
# 65/65 - 0s - 140us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/100
# 2024-03-31 13:11:15.696321: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:11:15.699699: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 42s - 645ms/step - auc: 0.9870 - loss: 0.1261 - val_auc: 0.9881 - val_loss: 0.1352
# Epoch 48/100
# 65/65 - 0s - 136us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/100
# 2024-03-31 13:11:57.618042: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:11:57.621163: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 46s - 706ms/step - auc: 0.9845 - loss: 0.1338 - val_auc: 0.9878 - val_loss: 0.1283
# Epoch 50/100
# 65/65 - 0s - 161us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/100
# 2024-03-31 13:12:43.506058: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:12:43.509844: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 674ms/step - auc: 0.9853 - loss: 0.1307 - val_auc: 0.9890 - val_loss: 0.1216
# Epoch 52/100
# 65/65 - 0s - 326us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/100
# 2024-03-31 13:13:27.326284: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:13:27.333728: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 665ms/step - auc: 0.9863 - loss: 0.1302 - val_auc: 0.9833 - val_loss: 0.1406
# Epoch 54/100
# 65/65 - 0s - 232us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/100
# 2024-03-31 13:14:10.566241: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:14:10.572224: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 658ms/step - auc: 0.9873 - loss: 0.1248 - val_auc: 0.9875 - val_loss: 0.1353
# Epoch 56/100
# 65/65 - 0s - 213us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 2024-03-31 13:14:53.337615: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:14:53.342739: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 658ms/step - auc: 0.9877 - loss: 0.1217 - val_auc: 0.9829 - val_loss: 0.1427
# Epoch 58/100
# 65/65 - 0s - 337us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 2024-03-31 13:15:36.100168: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:15:36.107888: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 677ms/step - auc: 0.9886 - loss: 0.1152 - val_auc: 0.9866 - val_loss: 0.1285
# Epoch 60/100
# 65/65 - 0s - 151us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 2024-03-31 13:16:20.107331: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:16:20.110769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 681ms/step - auc: 0.9890 - loss: 0.1155 - val_auc: 0.9881 - val_loss: 0.1272
# Epoch 62/100
# 65/65 - 0s - 204us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 2024-03-31 13:17:04.383436: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:17:04.388378: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 691ms/step - auc: 0.9895 - loss: 0.1149 - val_auc: 0.9879 - val_loss: 0.1222
# Epoch 64/100
# 65/65 - 0s - 281us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 2024-03-31 13:17:49.293713: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:17:49.301610: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 48s - 735ms/step - auc: 0.9876 - loss: 0.1191 - val_auc: 0.9850 - val_loss: 0.1382
# Epoch 66/100
# 65/65 - 0s - 167us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 2024-03-31 13:18:37.082590: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:18:37.086237: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 694ms/step - auc: 0.9895 - loss: 0.1136 - val_auc: 0.9826 - val_loss: 0.1530
# Epoch 68/100
# 65/65 - 0s - 561us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 2024-03-31 13:19:22.245061: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:19:22.250961: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 674ms/step - auc: 0.9907 - loss: 0.1051 - val_auc: 0.9864 - val_loss: 0.1343
# Epoch 70/100
# 65/65 - 0s - 215us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 2024-03-31 13:20:06.135098: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:20:06.140055: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 677ms/step - auc: 0.9888 - loss: 0.1144 - val_auc: 0.9905 - val_loss: 0.1290
# Epoch 72/100
# 65/65 - 0s - 164us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 2024-03-31 13:20:50.140592: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:20:50.144971: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 669ms/step - auc: 0.9893 - loss: 0.1091 - val_auc: 0.9845 - val_loss: 0.1399
# Epoch 74/100
# 65/65 - 0s - 152us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 2024-03-31 13:21:33.637032: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:21:33.640565: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 671ms/step - auc: 0.9890 - loss: 0.1117 - val_auc: 0.9848 - val_loss: 0.1353
# Epoch 76/100
# 65/65 - 0s - 129us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 2024-03-31 13:22:17.279817: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:22:17.282808: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 43s - 667ms/step - auc: 0.9894 - loss: 0.1126 - val_auc: 0.9892 - val_loss: 0.1664
# Epoch 78/100
# 65/65 - 0s - 138us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 2024-03-31 13:23:00.616373: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:23:00.619573: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 673ms/step - auc: 0.9911 - loss: 0.1056 - val_auc: 0.9894 - val_loss: 0.1513
# Epoch 80/100
# 65/65 - 0s - 157us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 2024-03-31 13:23:44.389841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:23:44.393579: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 689ms/step - auc: 0.9908 - loss: 0.1080 - val_auc: 0.9854 - val_loss: 0.1289
# Epoch 82/100
# 65/65 - 0s - 310us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 2024-03-31 13:24:29.172328: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:24:29.182666: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 46s - 706ms/step - auc: 0.9881 - loss: 0.1227 - val_auc: 0.9869 - val_loss: 0.1438
# Epoch 84/100
# 65/65 - 0s - 163us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 2024-03-31 13:25:15.080160: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:25:15.084422: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 45s - 689ms/step - auc: 0.9914 - loss: 0.1051 - val_auc: 0.9895 - val_loss: 0.1125
# Epoch 86/100
# 65/65 - 0s - 137us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 2024-03-31 13:25:59.911272: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:25:59.914296: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 44s - 682ms/step - auc: 0.9904 - loss: 0.1056 - val_auc: 0.9821 - val_loss: 0.1637
# Epoch 88/100
# 65/65 - 0s - 136us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 2024-03-31 13:26:44.230520: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:26:44.233456: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 47s - 720ms/step - auc: 0.9901 - loss: 0.1051 - val_auc: 0.9856 - val_loss: 0.1307
# Epoch 90/100
# 65/65 - 0s - 141us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 2024-03-31 13:27:31.047252: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:27:31.050298: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 35s - 535ms/step - auc: 0.9928 - loss: 0.0928 - val_auc: 0.9896 - val_loss: 0.1566
# Epoch 92/100
# 65/65 - 0s - 127us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 2024-03-31 13:28:05.829413: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:28:05.832415: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 30s - 467ms/step - auc: 0.9917 - loss: 0.0990 - val_auc: 0.9845 - val_loss: 0.1323
# Epoch 94/100
# 65/65 - 0s - 121us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 2024-03-31 13:28:36.204665: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:28:36.207395: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 30s - 464ms/step - auc: 0.9919 - loss: 0.0979 - val_auc: 0.9906 - val_loss: 0.1131
# Epoch 96/100
# 65/65 - 0s - 112us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 2024-03-31 13:29:06.380457: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:29:06.382954: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 30s - 455ms/step - auc: 0.9924 - loss: 0.0952 - val_auc: 0.9891 - val_loss: 0.1192
# Epoch 98/100
# 65/65 - 0s - 123us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 2024-03-31 13:29:35.986843: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:29:35.989598: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 65/65 - 30s - 463ms/step - auc: 0.9923 - loss: 0.0994 - val_auc: 0.9860 - val_loss: 0.1399
# Epoch 100/100
# 65/65 - 0s - 117us/step - auc: 0.0000e+00 - loss: 0.0000e+00 - val_auc: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 13:30:06.080834: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:30:06.083510: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step
# [Summary Statistics]
# Accuracy = 92.12% | Precision = 93.72% | Recall = 95.62% | Specificity = 82.63% | F1 Score = 94.66%

# %%
Model 8(a): Conv2D + (batch_size = 32) + (kernel = 5) + 128 dense units (100 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 100, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/100
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 129/129 - 27s - 210ms/step - auc_1: 0.6412 - loss: 0.5557 - val_auc_1: 0.9184 - val_loss: 0.4438
# Epoch 2/100
# 129/129 - 0s - 108us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/100
# 2024-03-31 13:44:08.996129: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 13:44:09.000725: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 33s - 257ms/step - auc_1: 0.9315 - loss: 0.2909 - val_auc_1: 0.9631 - val_loss: 0.2278
# Epoch 4/100
# 129/129 - 0s - 165us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/100
# 2024-03-31 13:44:42.150696: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:44:42.157415: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 38s - 292ms/step - auc_1: 0.9606 - loss: 0.2267 - val_auc_1: 0.9738 - val_loss: 0.1901
# Epoch 6/100
# 129/129 - 0s - 146us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/100
# 2024-03-31 13:45:19.827479: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:45:19.833140: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 41s - 321ms/step - auc_1: 0.9632 - loss: 0.2164 - val_auc_1: 0.9713 - val_loss: 0.3980
# Epoch 8/100
# 129/129 - 0s - 121us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/100
# 2024-03-31 13:46:01.279925: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:46:01.286838: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 337ms/step - auc_1: 0.9669 - loss: 0.2054 - val_auc_1: 0.9815 - val_loss: 0.1838
# Epoch 10/100
# 129/129 - 0s - 141us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/100
# 2024-03-31 13:46:44.779229: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:46:44.788736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 339ms/step - auc_1: 0.9738 - loss: 0.1818 - val_auc_1: 0.9850 - val_loss: 0.2605
# Epoch 12/100
# 129/129 - 0s - 72us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/100
# 2024-03-31 13:47:28.593107: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:47:28.596327: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 336ms/step - auc_1: 0.9734 - loss: 0.1798 - val_auc_1: 0.9838 - val_loss: 0.1576
# Epoch 14/100
# 129/129 - 0s - 189us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/100
# 2024-03-31 13:48:11.924411: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:48:11.931661: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 351ms/step - auc_1: 0.9768 - loss: 0.1715 - val_auc_1: 0.9839 - val_loss: 0.2467
# Epoch 16/100
# 129/129 - 0s - 140us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/100
# 2024-03-31 13:48:57.179493: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:48:57.185066: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 356ms/step - auc_1: 0.9789 - loss: 0.1644 - val_auc_1: 0.9861 - val_loss: 0.1572
# Epoch 18/100
# 129/129 - 0s - 126us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/100
# 2024-03-31 13:49:43.202062: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:49:43.207108: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 364ms/step - auc_1: 0.9793 - loss: 0.1600 - val_auc_1: 0.9855 - val_loss: 0.1619
# Epoch 20/100
# 129/129 - 0s - 152us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/100
# 2024-03-31 13:50:30.221807: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:50:30.232529: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 50s - 384ms/step - auc_1: 0.9787 - loss: 0.1619 - val_auc_1: 0.9809 - val_loss: 0.1811
# Epoch 22/100
# 129/129 - 0s - 148us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/100
# 2024-03-31 13:51:19.821736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:51:19.831503: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_1: 0.9831 - loss: 0.1453 - val_auc_1: 0.9855 - val_loss: 0.1440
# Epoch 24/100
# 129/129 - 0s - 81us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/100
# 2024-03-31 13:52:04.673331: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:52:04.676954: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 353ms/step - auc_1: 0.9822 - loss: 0.1476 - val_auc_1: 0.9867 - val_loss: 0.1394
# Epoch 26/100
# 129/129 - 0s - 79us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/100
# 2024-03-31 13:52:50.243693: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:52:50.247289: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 37s - 288ms/step - auc_1: 0.9832 - loss: 0.1421 - val_auc_1: 0.9878 - val_loss: 0.1372
# Epoch 28/100
# 129/129 - 0s - 60us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/100
# 2024-03-31 13:53:27.416619: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:53:27.419386: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 35s - 269ms/step - auc_1: 0.9842 - loss: 0.1363 - val_auc_1: 0.9845 - val_loss: 0.1409
# Epoch 30/100
# 129/129 - 0s - 106us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/100
# 2024-03-31 13:54:02.105214: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:54:02.110304: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_1: 0.9861 - loss: 0.1304 - val_auc_1: 0.9886 - val_loss: 0.1214
# Epoch 32/100
# 129/129 - 0s - 212us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/100
# 2024-03-31 13:54:46.367078: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:54:46.375525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 350ms/step - auc_1: 0.9861 - loss: 0.1285 - val_auc_1: 0.9850 - val_loss: 0.1396
# Epoch 34/100
# 129/129 - 0s - 138us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/100
# 2024-03-31 13:55:31.535892: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:55:31.544120: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 337ms/step - auc_1: 0.9872 - loss: 0.1230 - val_auc_1: 0.9884 - val_loss: 0.1275
# Epoch 36/100
# 129/129 - 0s - 271us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/100
# 2024-03-31 13:56:15.095257: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:56:15.103574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 335ms/step - auc_1: 0.9852 - loss: 0.1314 - val_auc_1: 0.9867 - val_loss: 0.1279
# Epoch 38/100
# 129/129 - 0s - 132us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/100
# 2024-03-31 13:56:58.290950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:56:58.297209: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_1: 0.9893 - loss: 0.1144 - val_auc_1: 0.9889 - val_loss: 0.1220
# Epoch 40/100
# 129/129 - 0s - 166us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/100
# 2024-03-31 13:57:41.956172: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:57:41.963212: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_1: 0.9879 - loss: 0.1208 - val_auc_1: 0.9865 - val_loss: 0.1440
# Epoch 42/100
# 129/129 - 0s - 245us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/100
# 2024-03-31 13:58:25.947906: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:58:25.958390: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 336ms/step - auc_1: 0.9859 - loss: 0.1271 - val_auc_1: 0.9886 - val_loss: 0.1325
# Epoch 44/100
# 129/129 - 0s - 80us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/100
# 2024-03-31 13:59:09.299552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:59:09.303130: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 335ms/step - auc_1: 0.9891 - loss: 0.1166 - val_auc_1: 0.9875 - val_loss: 0.1296
# Epoch 46/100
# 129/129 - 0s - 99us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/100
# 2024-03-31 13:59:52.567847: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 13:59:52.572479: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_1: 0.9871 - loss: 0.1254 - val_auc_1: 0.9916 - val_loss: 0.1271
# Epoch 48/100
# 129/129 - 0s - 161us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/100
# 2024-03-31 14:00:36.162536: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:00:36.170505: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 337ms/step - auc_1: 0.9892 - loss: 0.1129 - val_auc_1: 0.9895 - val_loss: 0.1298
# Epoch 50/100
# 129/129 - 0s - 96us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/100
# 2024-03-31 14:01:19.642991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:01:19.647751: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 337ms/step - auc_1: 0.9886 - loss: 0.1195 - val_auc_1: 0.9898 - val_loss: 0.1227
# Epoch 52/100
# 129/129 - 0s - 74us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/100
# 2024-03-31 14:02:03.130045: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:02:03.133177: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 344ms/step - auc_1: 0.9884 - loss: 0.1191 - val_auc_1: 0.9826 - val_loss: 0.1609
# Epoch 54/100
# 129/129 - 0s - 127us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/100
# 2024-03-31 14:02:47.545430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:02:47.552253: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_1: 0.9901 - loss: 0.1126 - val_auc_1: 0.9862 - val_loss: 0.1241
# Epoch 56/100
# 129/129 - 0s - 136us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 2024-03-31 14:03:31.795324: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:03:31.803673: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_1: 0.9916 - loss: 0.1018 - val_auc_1: 0.9795 - val_loss: 0.1692
# Epoch 58/100
# 129/129 - 0s - 172us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 2024-03-31 14:04:16.078731: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:04:16.086314: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 346ms/step - auc_1: 0.9887 - loss: 0.1141 - val_auc_1: 0.9870 - val_loss: 0.1349
# Epoch 60/100
# 129/129 - 0s - 121us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 2024-03-31 14:05:00.729920: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:05:00.736864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 339ms/step - auc_1: 0.9913 - loss: 0.1043 - val_auc_1: 0.9883 - val_loss: 0.1214
# Epoch 62/100
# 129/129 - 0s - 89us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 2024-03-31 14:05:44.428676: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:05:44.432305: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_1: 0.9924 - loss: 0.1007 - val_auc_1: 0.9869 - val_loss: 0.1403
# Epoch 64/100
# 129/129 - 0s - 140us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 2024-03-31 14:06:28.095342: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:06:28.104363: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 344ms/step - auc_1: 0.9889 - loss: 0.1109 - val_auc_1: 0.9897 - val_loss: 0.1257
# Epoch 66/100
# 129/129 - 0s - 177us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 2024-03-31 14:07:12.540594: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:07:12.551695: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 342ms/step - auc_1: 0.9908 - loss: 0.1038 - val_auc_1: 0.9848 - val_loss: 0.1385
# Epoch 68/100
# 129/129 - 0s - 76us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 2024-03-31 14:07:56.620633: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:07:56.623704: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 346ms/step - auc_1: 0.9927 - loss: 0.0948 - val_auc_1: 0.9874 - val_loss: 0.1410
# Epoch 70/100
# 129/129 - 0s - 78us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 2024-03-31 14:08:41.323574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:08:41.327270: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 334ms/step - auc_1: 0.9919 - loss: 0.1008 - val_auc_1: 0.9865 - val_loss: 0.1441
# Epoch 72/100
# 129/129 - 0s - 112us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 2024-03-31 14:09:24.446708: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:09:24.450276: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 336ms/step - auc_1: 0.9901 - loss: 0.1056 - val_auc_1: 0.9887 - val_loss: 0.1252
# Epoch 74/100
# 129/129 - 0s - 88us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 2024-03-31 14:10:07.823832: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:10:07.827602: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 334ms/step - auc_1: 0.9918 - loss: 0.0972 - val_auc_1: 0.9880 - val_loss: 0.1276
# Epoch 76/100
# 129/129 - 0s - 166us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 2024-03-31 14:10:50.903735: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:10:50.910176: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_1: 0.9907 - loss: 0.1047 - val_auc_1: 0.9895 - val_loss: 0.1157
# Epoch 78/100
# 129/129 - 0s - 179us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 2024-03-31 14:11:34.884231: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:11:34.892850: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_1: 0.9913 - loss: 0.1006 - val_auc_1: 0.9876 - val_loss: 0.1214
# Epoch 80/100
# 129/129 - 0s - 151us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 2024-03-31 14:12:18.782727: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:12:18.789555: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 343ms/step - auc_1: 0.9923 - loss: 0.0951 - val_auc_1: 0.9904 - val_loss: 0.1257
# Epoch 82/100
# 129/129 - 0s - 125us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 2024-03-31 14:13:03.021142: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:13:03.028606: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 335ms/step - auc_1: 0.9918 - loss: 0.0965 - val_auc_1: 0.9882 - val_loss: 0.1546
# Epoch 84/100
# 129/129 - 0s - 145us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 2024-03-31 14:13:46.268427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:13:46.277087: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 338ms/step - auc_1: 0.9915 - loss: 0.1000 - val_auc_1: 0.9884 - val_loss: 0.1316
# Epoch 86/100
# 129/129 - 0s - 74us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 2024-03-31 14:14:29.929263: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:14:29.932296: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 346ms/step - auc_1: 0.9941 - loss: 0.0863 - val_auc_1: 0.9882 - val_loss: 0.1235
# Epoch 88/100
# 129/129 - 0s - 118us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 2024-03-31 14:15:14.595377: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:15:14.600606: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 340ms/step - auc_1: 0.9917 - loss: 0.1047 - val_auc_1: 0.9860 - val_loss: 0.1248
# Epoch 90/100
# 129/129 - 0s - 74us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 2024-03-31 14:15:58.472443: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:15:58.475849: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 341ms/step - auc_1: 0.9919 - loss: 0.0980 - val_auc_1: 0.9913 - val_loss: 0.1280
# Epoch 92/100
# 129/129 - 0s - 135us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 2024-03-31 14:16:42.520853: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:16:42.528876: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 348ms/step - auc_1: 0.9930 - loss: 0.0921 - val_auc_1: 0.9886 - val_loss: 0.1294
# Epoch 94/100
# 129/129 - 0s - 144us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 2024-03-31 14:17:27.405565: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:17:27.412574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 363ms/step - auc_1: 0.9936 - loss: 0.0894 - val_auc_1: 0.9912 - val_loss: 0.1091
# Epoch 96/100
# 129/129 - 0s - 110us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 2024-03-31 14:18:14.247942: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:18:14.252953: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 346ms/step - auc_1: 0.9930 - loss: 0.0932 - val_auc_1: 0.9886 - val_loss: 0.1424
# Epoch 98/100
# 129/129 - 0s - 91us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 2024-03-31 14:18:58.949314: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:18:58.953236: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 342ms/step - auc_1: 0.9930 - loss: 0.0940 - val_auc_1: 0.9885 - val_loss: 0.1180
# Epoch 100/100
# 129/129 - 0s - 105us/step - auc_1: 0.0000e+00 - loss: 0.0000e+00 - val_auc_1: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 14:19:43.066327: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:19:43.071176: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step
# [Summary Statistics]
# Accuracy = 92.35% | Precision = 92.07% | Recall = 97.97% | Specificity = 77.12% | F1 Score = 94.93%

# %% [markdown]
# Model 8(b): Conv2D + (batch_size = 32) + (kernel = 5) + 128 dense units (400 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 400, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/400
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 129/129 - 28s - 217ms/step - auc_3: 0.6412 - loss: 0.5557 - val_auc_3: 0.9184 - val_loss: 0.4438
# Epoch 2/400
# 129/129 - 0s - 97us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/400
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 15:37:25.466793: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:37:25.470158: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 26s - 199ms/step - auc_3: 0.9315 - loss: 0.2909 - val_auc_3: 0.9631 - val_loss: 0.2278
# Epoch 4/400
# 129/129 - 0s - 71us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/400
# 2024-03-31 15:37:51.206365: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:37:51.209412: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 27s - 208ms/step - auc_3: 0.9606 - loss: 0.2267 - val_auc_3: 0.9738 - val_loss: 0.1901
# Epoch 6/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/400
# 2024-03-31 15:38:18.089813: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:38:18.092242: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9632 - loss: 0.2164 - val_auc_3: 0.9713 - val_loss: 0.3980
# Epoch 8/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/400
# 2024-03-31 15:38:46.364807: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:38:46.367179: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 229ms/step - auc_3: 0.9669 - loss: 0.2054 - val_auc_3: 0.9815 - val_loss: 0.1838
# Epoch 10/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/400
# 2024-03-31 15:39:15.970766: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:39:15.973183: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9738 - loss: 0.1818 - val_auc_3: 0.9850 - val_loss: 0.2605
# Epoch 12/400
# 129/129 - 0s - 72us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/400
# 2024-03-31 15:39:44.902192: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:39:44.905780: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_3: 0.9734 - loss: 0.1798 - val_auc_3: 0.9838 - val_loss: 0.1576
# Epoch 14/400
# 129/129 - 0s - 63us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/400
# 2024-03-31 15:40:15.261127: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:40:15.264166: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_3: 0.9768 - loss: 0.1715 - val_auc_3: 0.9839 - val_loss: 0.2467
# Epoch 16/400
# 129/129 - 0s - 67us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/400
# 2024-03-31 15:40:45.632081: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:40:45.634973: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9789 - loss: 0.1644 - val_auc_3: 0.9861 - val_loss: 0.1572
# Epoch 18/400
# 129/129 - 0s - 60us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/400
# 2024-03-31 15:41:14.527484: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:41:14.530103: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 215ms/step - auc_3: 0.9793 - loss: 0.1600 - val_auc_3: 0.9855 - val_loss: 0.1619
# Epoch 20/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/400
# 2024-03-31 15:41:42.293655: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:41:42.296199: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 216ms/step - auc_3: 0.9787 - loss: 0.1619 - val_auc_3: 0.9809 - val_loss: 0.1811
# Epoch 22/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/400
# 2024-03-31 15:42:10.107185: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:42:10.109596: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 214ms/step - auc_3: 0.9831 - loss: 0.1453 - val_auc_3: 0.9855 - val_loss: 0.1440
# Epoch 24/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/400
# 2024-03-31 15:42:37.761641: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:42:37.764074: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9822 - loss: 0.1476 - val_auc_3: 0.9867 - val_loss: 0.1394
# Epoch 26/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/400
# 2024-03-31 15:43:05.706214: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:43:05.708756: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 215ms/step - auc_3: 0.9832 - loss: 0.1421 - val_auc_3: 0.9878 - val_loss: 0.1372
# Epoch 28/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/400
# 2024-03-31 15:43:33.483413: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:43:33.486022: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 215ms/step - auc_3: 0.9842 - loss: 0.1363 - val_auc_3: 0.9845 - val_loss: 0.1409
# Epoch 30/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/400
# 2024-03-31 15:44:01.250292: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:44:01.252999: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 215ms/step - auc_3: 0.9861 - loss: 0.1304 - val_auc_3: 0.9886 - val_loss: 0.1214
# Epoch 32/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/400
# 2024-03-31 15:44:28.952576: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:44:28.955124: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 216ms/step - auc_3: 0.9861 - loss: 0.1285 - val_auc_3: 0.9850 - val_loss: 0.1396
# Epoch 34/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/400
# 2024-03-31 15:44:56.802446: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:44:56.804961: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9872 - loss: 0.1230 - val_auc_3: 0.9884 - val_loss: 0.1275
# Epoch 36/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/400
# 2024-03-31 15:45:24.960624: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:45:24.963191: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9852 - loss: 0.1314 - val_auc_3: 0.9867 - val_loss: 0.1279
# Epoch 38/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/400
# 2024-03-31 15:45:52.987815: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:45:52.990389: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9893 - loss: 0.1144 - val_auc_3: 0.9889 - val_loss: 0.1220
# Epoch 40/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/400
# 2024-03-31 15:46:21.120871: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:46:21.123441: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9879 - loss: 0.1208 - val_auc_3: 0.9865 - val_loss: 0.1440
# Epoch 42/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/400
# 2024-03-31 15:46:49.239254: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:46:49.241877: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 221ms/step - auc_3: 0.9859 - loss: 0.1271 - val_auc_3: 0.9886 - val_loss: 0.1325
# Epoch 44/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/400
# 2024-03-31 15:47:17.703685: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:47:17.706259: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9891 - loss: 0.1166 - val_auc_3: 0.9875 - val_loss: 0.1296
# Epoch 46/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/400
# 2024-03-31 15:47:45.963825: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:47:45.966357: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9871 - loss: 0.1254 - val_auc_3: 0.9916 - val_loss: 0.1271
# Epoch 48/400
# 129/129 - 0s - 61us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/400
# 2024-03-31 15:48:14.022121: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:48:14.024743: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9892 - loss: 0.1129 - val_auc_3: 0.9895 - val_loss: 0.1298
# Epoch 50/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/400
# 2024-03-31 15:48:42.259517: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:48:42.262091: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9886 - loss: 0.1195 - val_auc_3: 0.9898 - val_loss: 0.1227
# Epoch 52/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/400
# 2024-03-31 15:49:10.578915: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:49:10.581469: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9884 - loss: 0.1191 - val_auc_3: 0.9826 - val_loss: 0.1609
# Epoch 54/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/400
# 2024-03-31 15:49:38.720243: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:49:38.722796: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9901 - loss: 0.1126 - val_auc_3: 0.9862 - val_loss: 0.1241
# Epoch 56/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/400
# 2024-03-31 15:50:06.870965: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:50:06.873537: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9916 - loss: 0.1018 - val_auc_3: 0.9795 - val_loss: 0.1692
# Epoch 58/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/400
# 2024-03-31 15:50:35.190683: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:50:35.193226: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9887 - loss: 0.1141 - val_auc_3: 0.9870 - val_loss: 0.1349
# Epoch 60/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/400
# 2024-03-31 15:51:03.625613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:51:03.628101: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9913 - loss: 0.1043 - val_auc_3: 0.9883 - val_loss: 0.1214
# Epoch 62/400
# 129/129 - 0s - 52us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/400
# 2024-03-31 15:51:31.830206: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:51:31.832562: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9924 - loss: 0.1007 - val_auc_3: 0.9869 - val_loss: 0.1403
# Epoch 64/400
# 129/129 - 0s - 62us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/400
# 2024-03-31 15:51:59.882893: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:51:59.885711: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9889 - loss: 0.1109 - val_auc_3: 0.9897 - val_loss: 0.1257
# Epoch 66/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/400
# 2024-03-31 15:52:28.005997: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:52:28.008544: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9908 - loss: 0.1038 - val_auc_3: 0.9848 - val_loss: 0.1385
# Epoch 68/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/400
# 2024-03-31 15:52:56.022690: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:52:56.025227: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9927 - loss: 0.0948 - val_auc_3: 0.9874 - val_loss: 0.1410
# Epoch 70/400
# 129/129 - 0s - 62us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/400
# 2024-03-31 15:53:24.059652: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:53:24.062254: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9919 - loss: 0.1008 - val_auc_3: 0.9865 - val_loss: 0.1441
# Epoch 72/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/400
# 2024-03-31 15:53:52.008800: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:53:52.011475: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9901 - loss: 0.1056 - val_auc_3: 0.9887 - val_loss: 0.1252
# Epoch 74/400
# 129/129 - 0s - 51us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/400
# 2024-03-31 15:54:20.113307: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:54:20.115606: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9918 - loss: 0.0972 - val_auc_3: 0.9880 - val_loss: 0.1276
# Epoch 76/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/400
# 2024-03-31 15:54:48.067094: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:54:48.069293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9907 - loss: 0.1047 - val_auc_3: 0.9895 - val_loss: 0.1157
# Epoch 78/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/400
# 2024-03-31 15:55:16.097293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:55:16.099931: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9913 - loss: 0.1006 - val_auc_3: 0.9876 - val_loss: 0.1214
# Epoch 80/400
# 129/129 - 0s - 66us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/400
# 2024-03-31 15:55:44.384861: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:55:44.387900: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9923 - loss: 0.0951 - val_auc_3: 0.9904 - val_loss: 0.1257
# Epoch 82/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/400
# 2024-03-31 15:56:12.516462: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:56:12.519179: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9918 - loss: 0.0965 - val_auc_3: 0.9882 - val_loss: 0.1546
# Epoch 84/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/400
# 2024-03-31 15:56:40.604751: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:56:40.607820: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9915 - loss: 0.1000 - val_auc_3: 0.9884 - val_loss: 0.1316
# Epoch 86/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/400
# 2024-03-31 15:57:08.830754: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:57:08.833336: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9941 - loss: 0.0863 - val_auc_3: 0.9882 - val_loss: 0.1235
# Epoch 88/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/400
# 2024-03-31 15:57:36.945412: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:57:36.947871: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 217ms/step - auc_3: 0.9917 - loss: 0.1047 - val_auc_3: 0.9860 - val_loss: 0.1248
# Epoch 90/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/400
# 2024-03-31 15:58:04.972769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:58:04.975252: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 221ms/step - auc_3: 0.9919 - loss: 0.0980 - val_auc_3: 0.9913 - val_loss: 0.1280
# Epoch 92/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/400
# 2024-03-31 15:58:33.461779: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:58:33.464176: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 221ms/step - auc_3: 0.9930 - loss: 0.0921 - val_auc_3: 0.9886 - val_loss: 0.1294
# Epoch 94/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/400
# 2024-03-31 15:59:01.963513: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:59:01.966129: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9936 - loss: 0.0894 - val_auc_3: 0.9912 - val_loss: 0.1091
# Epoch 96/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/400
# 2024-03-31 15:59:30.259248: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:59:30.261792: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9930 - loss: 0.0932 - val_auc_3: 0.9886 - val_loss: 0.1424
# Epoch 98/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/400
# 2024-03-31 15:59:58.403579: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:59:58.406341: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9930 - loss: 0.0940 - val_auc_3: 0.9885 - val_loss: 0.1180
# Epoch 100/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 101/400
# 2024-03-31 16:00:26.935029: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:00:26.937600: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_3: 0.9930 - loss: 0.0911 - val_auc_3: 0.9892 - val_loss: 0.1401
# Epoch 102/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 103/400
# 2024-03-31 16:00:55.745305: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:00:55.747738: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 221ms/step - auc_3: 0.9940 - loss: 0.0855 - val_auc_3: 0.9875 - val_loss: 0.1296
# Epoch 104/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 105/400
# 2024-03-31 16:01:24.242795: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:01:24.245358: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9934 - loss: 0.0903 - val_auc_3: 0.9911 - val_loss: 0.1092
# Epoch 106/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 107/400
# 2024-03-31 16:01:52.762245: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:01:52.764911: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9901 - loss: 0.1118 - val_auc_3: 0.9892 - val_loss: 0.1101
# Epoch 108/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 109/400
# 2024-03-31 16:02:21.209098: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:02:21.211673: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9934 - loss: 0.0890 - val_auc_3: 0.9843 - val_loss: 0.1323
# Epoch 110/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 111/400
# 2024-03-31 16:02:49.754924: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:02:49.757449: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9942 - loss: 0.0820 - val_auc_3: 0.9886 - val_loss: 0.1867
# Epoch 112/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 113/400
# 2024-03-31 16:03:18.298809: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:03:18.301484: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9943 - loss: 0.0844 - val_auc_3: 0.9877 - val_loss: 0.1352
# Epoch 114/400
# 129/129 - 0s - 60us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 115/400
# 2024-03-31 16:03:46.822950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:03:46.825605: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9942 - loss: 0.0795 - val_auc_3: 0.9851 - val_loss: 0.1754
# Epoch 116/400
# 129/129 - 0s - 60us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 117/400
# 2024-03-31 16:04:15.075355: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:04:15.078091: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9942 - loss: 0.0785 - val_auc_3: 0.9892 - val_loss: 0.1147
# Epoch 118/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 119/400
# 2024-03-31 16:04:43.205252: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:04:43.207864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9943 - loss: 0.0814 - val_auc_3: 0.9873 - val_loss: 0.1227
# Epoch 120/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 121/400
# 2024-03-31 16:05:11.284613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:05:11.287112: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9934 - loss: 0.0846 - val_auc_3: 0.9897 - val_loss: 0.1272
# Epoch 122/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 123/400
# 2024-03-31 16:05:39.481724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:05:39.484334: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 218ms/step - auc_3: 0.9949 - loss: 0.0754 - val_auc_3: 0.9855 - val_loss: 0.1230
# Epoch 124/400
# 129/129 - 0s - 62us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 125/400
# 2024-03-31 16:06:07.552709: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:06:07.555413: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9922 - loss: 0.0913 - val_auc_3: 0.9881 - val_loss: 0.1551
# Epoch 126/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 127/400
# 2024-03-31 16:06:35.971630: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:06:35.974059: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_3: 0.9943 - loss: 0.0778 - val_auc_3: 0.9888 - val_loss: 0.1385
# Epoch 128/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 129/400
# 2024-03-31 16:07:04.805037: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:07:04.807356: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_3: 0.9942 - loss: 0.0822 - val_auc_3: 0.9915 - val_loss: 0.1511
# Epoch 130/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 131/400
# 2024-03-31 16:07:33.605595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:07:33.608120: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_3: 0.9945 - loss: 0.0761 - val_auc_3: 0.9888 - val_loss: 0.1203
# Epoch 132/400
# 129/129 - 0s - 62us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 133/400
# 2024-03-31 16:08:02.265772: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:08:02.268415: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9947 - loss: 0.0829 - val_auc_3: 0.9904 - val_loss: 0.1209
# Epoch 134/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 135/400
# 2024-03-31 16:08:30.832473: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:08:30.835132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9949 - loss: 0.0753 - val_auc_3: 0.9886 - val_loss: 0.1319
# Epoch 136/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 137/400
# 2024-03-31 16:08:59.183515: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:08:59.185971: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 219ms/step - auc_3: 0.9948 - loss: 0.0747 - val_auc_3: 0.9905 - val_loss: 0.1071
# Epoch 138/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 139/400
# 2024-03-31 16:09:27.398146: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:09:27.400604: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9956 - loss: 0.0718 - val_auc_3: 0.9895 - val_loss: 0.1136
# Epoch 140/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 141/400
# 2024-03-31 16:09:55.754610: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:09:55.757147: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 221ms/step - auc_3: 0.9941 - loss: 0.0758 - val_auc_3: 0.9883 - val_loss: 0.1313
# Epoch 142/400
# 129/129 - 0s - 61us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 143/400
# 2024-03-31 16:10:24.244574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:10:24.247308: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9940 - loss: 0.0843 - val_auc_3: 0.9907 - val_loss: 0.1057
# Epoch 144/400
# 129/129 - 0s - 52us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 145/400
# 2024-03-31 16:10:52.806161: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:10:52.808490: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9954 - loss: 0.0769 - val_auc_3: 0.9882 - val_loss: 0.1197
# Epoch 146/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 147/400
# 2024-03-31 16:11:21.231521: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:11:21.234227: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9955 - loss: 0.0720 - val_auc_3: 0.9890 - val_loss: 0.1213
# Epoch 148/400
# 129/129 - 0s - 52us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 149/400
# 2024-03-31 16:11:49.578052: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:11:49.580411: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9957 - loss: 0.0704 - val_auc_3: 0.9900 - val_loss: 0.1350
# Epoch 150/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 151/400
# 2024-03-31 16:12:18.095816: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:12:18.098433: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9963 - loss: 0.0671 - val_auc_3: 0.9898 - val_loss: 0.1143
# Epoch 152/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 153/400
# 2024-03-31 16:12:46.423078: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:12:46.425678: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_3: 0.9955 - loss: 0.0764 - val_auc_3: 0.9918 - val_loss: 0.1046
# Epoch 154/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 155/400
# 2024-03-31 16:13:15.098527: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:13:15.100976: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_3: 0.9957 - loss: 0.0663 - val_auc_3: 0.9906 - val_loss: 0.1238
# Epoch 156/400
# 129/129 - 0s - 53us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 157/400
# 2024-03-31 16:13:43.467132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 16:13:43.469721: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9961 - loss: 0.0667 - val_auc_3: 0.9884 - val_loss: 0.1330
# Epoch 158/400
# ...
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9986 - loss: 0.0406 - val_auc_3: 0.9899 - val_loss: 0.1193
# Epoch 350/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 351/400
# 2024-03-31 17:00:50.855420: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:00:50.858043: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 226ms/step - auc_3: 0.9990 - loss: 0.0349 - val_auc_3: 0.9826 - val_loss: 0.1491
# Epoch 352/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 353/400
# 2024-03-31 17:01:19.983397: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:01:19.986065: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9981 - loss: 0.0372 - val_auc_3: 0.9877 - val_loss: 0.1486
# Epoch 354/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 355/400
# 2024-03-31 17:01:49.031619: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:01:49.034177: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_3: 0.9977 - loss: 0.0382 - val_auc_3: 0.9849 - val_loss: 0.1361
# Epoch 356/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 357/400
# 2024-03-31 17:02:17.671193: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:02:17.673835: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9988 - loss: 0.0388 - val_auc_3: 0.9867 - val_loss: 0.2149
# Epoch 358/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 359/400
# 2024-03-31 17:02:46.667572: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:02:46.669917: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9992 - loss: 0.0319 - val_auc_3: 0.9883 - val_loss: 0.1881
# Epoch 360/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 361/400
# 2024-03-31 17:03:15.661967: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:03:15.664664: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9989 - loss: 0.0302 - val_auc_3: 0.9790 - val_loss: 0.1683
# Epoch 362/400
# 129/129 - 0s - 60us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 363/400
# 2024-03-31 17:03:44.579036: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:03:44.581820: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_3: 0.9992 - loss: 0.0328 - val_auc_3: 0.9886 - val_loss: 0.1472
# Epoch 364/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 365/400
# 2024-03-31 17:04:13.206477: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:04:13.209032: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9992 - loss: 0.0289 - val_auc_3: 0.9855 - val_loss: 0.1466
# Epoch 366/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 367/400
# 2024-03-31 17:04:42.273428: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:04:42.275983: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 226ms/step - auc_3: 0.9977 - loss: 0.0344 - val_auc_3: 0.9802 - val_loss: 0.1524
# Epoch 368/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 369/400
# 2024-03-31 17:05:11.457628: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:05:11.460454: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9987 - loss: 0.0323 - val_auc_3: 0.9853 - val_loss: 0.1769
# Epoch 370/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 371/400
# 2024-03-31 17:05:40.466830: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:05:40.469437: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 221ms/step - auc_3: 0.9988 - loss: 0.0326 - val_auc_3: 0.9896 - val_loss: 0.1406
# Epoch 372/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 373/400
# 2024-03-31 17:06:08.993227: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:06:08.995976: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9991 - loss: 0.0340 - val_auc_3: 0.9817 - val_loss: 0.1423
# Epoch 374/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 375/400
# 2024-03-31 17:06:38.008014: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:06:38.010613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 226ms/step - auc_3: 0.9986 - loss: 0.0348 - val_auc_3: 0.9879 - val_loss: 0.1345
# Epoch 376/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 377/400
# 2024-03-31 17:07:07.165442: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:07:07.168144: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_3: 0.9980 - loss: 0.0404 - val_auc_3: 0.9913 - val_loss: 0.1139
# Epoch 378/400
# 129/129 - 0s - 57us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 379/400
# 2024-03-31 17:07:36.806655: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:07:36.809379: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 226ms/step - auc_3: 0.9990 - loss: 0.0335 - val_auc_3: 0.9919 - val_loss: 0.1345
# Epoch 380/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 381/400
# 2024-03-31 17:08:06.028038: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:08:06.030687: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_3: 0.9984 - loss: 0.0404 - val_auc_3: 0.9849 - val_loss: 0.2574
# Epoch 382/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 383/400
# 2024-03-31 17:08:34.747997: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:08:34.750575: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9987 - loss: 0.0383 - val_auc_3: 0.9840 - val_loss: 0.1537
# Epoch 384/400
# 129/129 - 0s - 55us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 385/400
# 2024-03-31 17:09:03.626715: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:09:03.629196: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9987 - loss: 0.0332 - val_auc_3: 0.9875 - val_loss: 0.1402
# Epoch 386/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 387/400
# 2024-03-31 17:09:32.524150: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:09:32.526663: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_3: 0.9993 - loss: 0.0286 - val_auc_3: 0.9866 - val_loss: 0.1530
# Epoch 388/400
# 129/129 - 0s - 65us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 389/400
# 2024-03-31 17:10:01.857229: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:10:01.860247: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_3: 0.9988 - loss: 0.0290 - val_auc_3: 0.9892 - val_loss: 0.1502
# Epoch 390/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 391/400
# 2024-03-31 17:10:30.459602: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:10:30.462332: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9995 - loss: 0.0259 - val_auc_3: 0.9865 - val_loss: 0.1643
# Epoch 392/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 393/400
# 2024-03-31 17:10:59.474095: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:10:59.476872: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_3: 0.9986 - loss: 0.0268 - val_auc_3: 0.9850 - val_loss: 0.1528
# Epoch 394/400
# 129/129 - 0s - 59us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 395/400
# 2024-03-31 17:11:28.423370: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:11:28.426050: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9990 - loss: 0.0353 - val_auc_3: 0.9870 - val_loss: 0.1322
# Epoch 396/400
# 129/129 - 0s - 56us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 397/400
# 2024-03-31 17:11:57.415088: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:11:57.417619: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_3: 0.9995 - loss: 0.0253 - val_auc_3: 0.9882 - val_loss: 0.1357
# Epoch 398/400
# 129/129 - 0s - 54us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 399/400
# 2024-03-31 17:12:26.459001: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:12:26.461561: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_3: 0.9990 - loss: 0.0286 - val_auc_3: 0.9907 - val_loss: 0.1393
# Epoch 400/400
# 129/129 - 0s - 58us/step - auc_3: 0.0000e+00 - loss: 0.0000e+00 - val_auc_3: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 17:12:55.249958: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 17:12:55.252875: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step
# [Summary Statistics]
# Accuracy = 91.10% | Precision = 93.23% | Recall = 94.69% | Specificity = 81.36% | F1 Score = 93.95%

# %% [markdown]
# Model 7(b): Conv2D + (batch_size = 64) + (kernel = 5) + 128 dense units (200 epochs)

# %%
# basics
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import pickle 

# Keras Libraries
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import keras.backend

# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

project_path = "/Users/freazx/Documents/ONE TAB/CODING"
train_path = project_path + "/chest_xray/setB/train/"
val_path = project_path + "/chest_xray/setB/val/"
test_path = project_path + "/chest_xray/setB/test/"

hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100

## Training in grayscale instead of RGB
hyper_channels = 1
hyper_mode = 'grayscale'

train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 

train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()

def create_charts(cnn, cnn_model):
    ## Define train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict(test_generator, steps=len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
    # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Pneumonia']

    # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
     ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)
    
#cnn
hyper_feature_maps = 64
cnn = Sequential()
cnn.add(InputLayer(shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=hyper_feature_maps, kernel_size=5, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 200, 
                              validation_data = val_generator,
                              validation_steps = len(val_generator), 
                              verbose=2)

create_charts(cnn, cnn_model)
# Out:
# Found 4104 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.
# Found 876 images belonging to 2 classes.
# Epoch 1/200
# /Users/freazx/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 129/129 - 36s - 283ms/step - auc_2: 0.6412 - loss: 0.5557 - val_auc_2: 0.9184 - val_loss: 0.4438
# Epoch 2/200
# 129/129 - 0s - 111us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/200
# 2024-03-31 14:32:08.965941: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/freazx/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 2024-03-31 14:32:08.969552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 39s - 300ms/step - auc_2: 0.9315 - loss: 0.2909 - val_auc_2: 0.9631 - val_loss: 0.2278
# Epoch 4/200
# 129/129 - 0s - 76us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/200
# 2024-03-31 14:32:47.741943: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:32:47.745414: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 41s - 317ms/step - auc_2: 0.9606 - loss: 0.2267 - val_auc_2: 0.9738 - val_loss: 0.1901
# Epoch 6/200
# 129/129 - 0s - 72us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/200
# 2024-03-31 14:33:28.660097: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:33:28.663214: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 42s - 327ms/step - auc_2: 0.9632 - loss: 0.2164 - val_auc_2: 0.9713 - val_loss: 0.3980
# Epoch 8/200
# 129/129 - 0s - 144us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/200
# 2024-03-31 14:34:10.923106: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:34:10.931811: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 42s - 327ms/step - auc_2: 0.9669 - loss: 0.2054 - val_auc_2: 0.9815 - val_loss: 0.1838
# Epoch 10/200
# 129/129 - 0s - 72us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/200
# 2024-03-31 14:34:53.163981: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:34:53.167129: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 43s - 332ms/step - auc_2: 0.9738 - loss: 0.1818 - val_auc_2: 0.9850 - val_loss: 0.2605
# Epoch 12/200
# 129/129 - 0s - 150us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/200
# 2024-03-31 14:35:36.015196: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:35:36.024655: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 42s - 327ms/step - auc_2: 0.9734 - loss: 0.1798 - val_auc_2: 0.9838 - val_loss: 0.1576
# Epoch 14/200
# 129/129 - 0s - 72us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/200
# 2024-03-31 14:36:18.218030: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:36:18.221053: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 345ms/step - auc_2: 0.9768 - loss: 0.1715 - val_auc_2: 0.9839 - val_loss: 0.2467
# Epoch 16/200
# 129/129 - 0s - 105us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/200
# 2024-03-31 14:37:02.723487: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:37:02.728533: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 373ms/step - auc_2: 0.9789 - loss: 0.1644 - val_auc_2: 0.9861 - val_loss: 0.1572
# Epoch 18/200
# 129/129 - 0s - 172us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/200
# 2024-03-31 14:37:50.842860: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:37:50.850823: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 51s - 398ms/step - auc_2: 0.9793 - loss: 0.1600 - val_auc_2: 0.9855 - val_loss: 0.1619
# Epoch 20/200
# 129/129 - 0s - 102us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/200
# 2024-03-31 14:38:42.165577: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:38:42.170377: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 50s - 385ms/step - auc_2: 0.9787 - loss: 0.1619 - val_auc_2: 0.9809 - val_loss: 0.1811
# Epoch 22/200
# 129/129 - 0s - 140us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/200
# 2024-03-31 14:39:31.888978: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:39:31.896185: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 44s - 345ms/step - auc_2: 0.9831 - loss: 0.1453 - val_auc_2: 0.9855 - val_loss: 0.1440
# Epoch 24/200
# 129/129 - 0s - 170us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/200
# 2024-03-31 14:40:16.362787: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:40:16.370643: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 353ms/step - auc_2: 0.9822 - loss: 0.1476 - val_auc_2: 0.9867 - val_loss: 0.1394
# Epoch 26/200
# 129/129 - 0s - 151us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/200
# 2024-03-31 14:41:01.896724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:41:01.906272: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 351ms/step - auc_2: 0.9832 - loss: 0.1421 - val_auc_2: 0.9878 - val_loss: 0.1372
# Epoch 28/200
# 129/129 - 0s - 147us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/200
# 2024-03-31 14:41:47.205691: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:41:47.214334: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 347ms/step - auc_2: 0.9842 - loss: 0.1363 - val_auc_2: 0.9845 - val_loss: 0.1409
# Epoch 30/200
# 129/129 - 0s - 78us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/200
# 2024-03-31 14:42:32.038853: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:42:32.042675: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 355ms/step - auc_2: 0.9861 - loss: 0.1304 - val_auc_2: 0.9886 - val_loss: 0.1214
# Epoch 32/200
# 129/129 - 0s - 122us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/200
# 2024-03-31 14:43:17.872362: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:43:17.878410: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 358ms/step - auc_2: 0.9861 - loss: 0.1285 - val_auc_2: 0.9850 - val_loss: 0.1396
# Epoch 34/200
# 129/129 - 0s - 77us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/200
# 2024-03-31 14:44:04.116986: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:44:04.120386: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 361ms/step - auc_2: 0.9872 - loss: 0.1230 - val_auc_2: 0.9884 - val_loss: 0.1275
# Epoch 36/200
# 129/129 - 0s - 87us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/200
# 2024-03-31 14:44:50.685118: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:44:50.688881: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 352ms/step - auc_2: 0.9852 - loss: 0.1314 - val_auc_2: 0.9867 - val_loss: 0.1279
# Epoch 38/200
# 129/129 - 0s - 96us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/200
# 2024-03-31 14:45:36.118235: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:45:36.122589: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 45s - 348ms/step - auc_2: 0.9893 - loss: 0.1144 - val_auc_2: 0.9889 - val_loss: 0.1220
# Epoch 40/200
# 129/129 - 0s - 69us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/200
# 2024-03-31 14:46:21.017020: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:46:21.020117: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 360ms/step - auc_2: 0.9879 - loss: 0.1208 - val_auc_2: 0.9865 - val_loss: 0.1440
# Epoch 42/200
# 129/129 - 0s - 161us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/200
# 2024-03-31 14:47:07.421091: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:47:07.431985: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 363ms/step - auc_2: 0.9859 - loss: 0.1271 - val_auc_2: 0.9886 - val_loss: 0.1325
# Epoch 44/200
# 129/129 - 0s - 70us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/200
# 2024-03-31 14:47:54.225576: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:47:54.228712: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 365ms/step - auc_2: 0.9891 - loss: 0.1166 - val_auc_2: 0.9875 - val_loss: 0.1296
# Epoch 46/200
# 129/129 - 0s - 67us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/200
# 2024-03-31 14:48:41.321247: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:48:41.324240: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 359ms/step - auc_2: 0.9871 - loss: 0.1254 - val_auc_2: 0.9916 - val_loss: 0.1271
# Epoch 48/200
# 129/129 - 0s - 72us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/200
# 2024-03-31 14:49:27.665584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:49:27.668890: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 360ms/step - auc_2: 0.9892 - loss: 0.1129 - val_auc_2: 0.9895 - val_loss: 0.1298
# Epoch 50/200
# 129/129 - 0s - 127us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/200
# 2024-03-31 14:50:14.098266: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:50:14.101460: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 358ms/step - auc_2: 0.9886 - loss: 0.1195 - val_auc_2: 0.9898 - val_loss: 0.1227
# Epoch 52/200
# 129/129 - 0s - 174us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 53/200
# 2024-03-31 14:51:00.257736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:51:00.266368: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 365ms/step - auc_2: 0.9884 - loss: 0.1191 - val_auc_2: 0.9826 - val_loss: 0.1609
# Epoch 54/200
# 129/129 - 0s - 168us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 55/200
# 2024-03-31 14:51:47.329637: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:51:47.337542: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 361ms/step - auc_2: 0.9901 - loss: 0.1126 - val_auc_2: 0.9862 - val_loss: 0.1241
# Epoch 56/200
# 129/129 - 0s - 85us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/200
# 2024-03-31 14:52:33.967018: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:52:33.970777: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 354ms/step - auc_2: 0.9916 - loss: 0.1018 - val_auc_2: 0.9795 - val_loss: 0.1692
# Epoch 58/200
# 129/129 - 0s - 124us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/200
# 2024-03-31 14:53:19.683261: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:53:19.688340: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 358ms/step - auc_2: 0.9887 - loss: 0.1141 - val_auc_2: 0.9870 - val_loss: 0.1349
# Epoch 60/200
# 129/129 - 0s - 153us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/200
# 2024-03-31 14:54:05.915525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:54:05.921709: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 375ms/step - auc_2: 0.9913 - loss: 0.1043 - val_auc_2: 0.9883 - val_loss: 0.1214
# Epoch 62/200
# 129/129 - 0s - 158us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/200
# 2024-03-31 14:54:54.293343: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:54:54.302340: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 366ms/step - auc_2: 0.9924 - loss: 0.1007 - val_auc_2: 0.9869 - val_loss: 0.1403
# Epoch 64/200
# 129/129 - 0s - 86us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/200
# 2024-03-31 14:55:41.526540: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:55:41.530357: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 365ms/step - auc_2: 0.9889 - loss: 0.1109 - val_auc_2: 0.9897 - val_loss: 0.1257
# Epoch 66/200
# 129/129 - 0s - 110us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/200
# 2024-03-31 14:56:28.599864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:56:28.604652: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 370ms/step - auc_2: 0.9908 - loss: 0.1038 - val_auc_2: 0.9848 - val_loss: 0.1385
# Epoch 68/200
# 129/129 - 0s - 172us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/200
# 2024-03-31 14:57:16.295397: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:57:16.300895: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 369ms/step - auc_2: 0.9927 - loss: 0.0948 - val_auc_2: 0.9874 - val_loss: 0.1410
# Epoch 70/200
# 129/129 - 0s - 107us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/200
# 2024-03-31 14:58:03.868626: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:58:03.873379: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 369ms/step - auc_2: 0.9919 - loss: 0.1008 - val_auc_2: 0.9865 - val_loss: 0.1441
# Epoch 72/200
# 129/129 - 0s - 75us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/200
# 2024-03-31 14:58:51.509681: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:58:51.513251: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 368ms/step - auc_2: 0.9901 - loss: 0.1056 - val_auc_2: 0.9887 - val_loss: 0.1252
# Epoch 74/200
# 129/129 - 0s - 166us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/200
# 2024-03-31 14:59:39.013038: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 14:59:39.021220: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 50s - 389ms/step - auc_2: 0.9918 - loss: 0.0972 - val_auc_2: 0.9880 - val_loss: 0.1276
# Epoch 76/200
# 129/129 - 0s - 201us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/200
# 2024-03-31 15:00:29.282060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:00:29.292825: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 51s - 392ms/step - auc_2: 0.9907 - loss: 0.1047 - val_auc_2: 0.9895 - val_loss: 0.1157
# Epoch 78/200
# 129/129 - 0s - 119us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/200
# 2024-03-31 15:01:19.914913: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:01:19.920414: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 366ms/step - auc_2: 0.9913 - loss: 0.1006 - val_auc_2: 0.9876 - val_loss: 0.1214
# Epoch 80/200
# 129/129 - 0s - 90us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/200
# 2024-03-31 15:02:07.211444: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:02:07.215474: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 365ms/step - auc_2: 0.9923 - loss: 0.0951 - val_auc_2: 0.9904 - val_loss: 0.1257
# Epoch 82/200
# 129/129 - 0s - 69us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/200
# 2024-03-31 15:02:54.311405: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:02:54.314446: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 374ms/step - auc_2: 0.9918 - loss: 0.0965 - val_auc_2: 0.9882 - val_loss: 0.1546
# Epoch 84/200
# 129/129 - 0s - 67us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/200
# 2024-03-31 15:03:42.621998: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:03:42.625066: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 374ms/step - auc_2: 0.9915 - loss: 0.1000 - val_auc_2: 0.9884 - val_loss: 0.1316
# Epoch 86/200
# 129/129 - 0s - 89us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/200
# 2024-03-31 15:04:30.862495: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:04:30.866376: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 49s - 379ms/step - auc_2: 0.9941 - loss: 0.0863 - val_auc_2: 0.9882 - val_loss: 0.1235
# Epoch 88/200
# 129/129 - 0s - 98us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/200
# 2024-03-31 15:05:19.741707: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:05:19.746129: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 370ms/step - auc_2: 0.9917 - loss: 0.1047 - val_auc_2: 0.9860 - val_loss: 0.1248
# Epoch 90/200
# 129/129 - 0s - 82us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/200
# 2024-03-31 15:06:07.424628: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:06:07.428964: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 362ms/step - auc_2: 0.9919 - loss: 0.0980 - val_auc_2: 0.9913 - val_loss: 0.1280
# Epoch 92/200
# 129/129 - 0s - 218us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/200
# 2024-03-31 15:06:54.176897: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:06:54.190288: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 354ms/step - auc_2: 0.9930 - loss: 0.0921 - val_auc_2: 0.9886 - val_loss: 0.1294
# Epoch 94/200
# 129/129 - 0s - 127us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/200
# 2024-03-31 15:07:39.866025: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:07:39.872311: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 360ms/step - auc_2: 0.9936 - loss: 0.0894 - val_auc_2: 0.9912 - val_loss: 0.1091
# Epoch 96/200
# 129/129 - 0s - 114us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/200
# 2024-03-31 15:08:26.356180: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:08:26.360984: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 47s - 366ms/step - auc_2: 0.9930 - loss: 0.0932 - val_auc_2: 0.9886 - val_loss: 0.1424
# Epoch 98/200
# 129/129 - 0s - 122us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/200
# 2024-03-31 15:09:13.537845: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:09:13.543574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 46s - 355ms/step - auc_2: 0.9930 - loss: 0.0940 - val_auc_2: 0.9885 - val_loss: 0.1180
# Epoch 100/200
# 129/129 - 0s - 518us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 101/200
# 2024-03-31 15:09:59.406475: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:09:59.411667: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 48s - 374ms/step - auc_2: 0.9930 - loss: 0.0911 - val_auc_2: 0.9892 - val_loss: 0.1401
# Epoch 102/200
# 129/129 - 0s - 167us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 103/200
# 2024-03-31 15:10:47.735608: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:10:47.741086: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 39s - 302ms/step - auc_2: 0.9940 - loss: 0.0855 - val_auc_2: 0.9875 - val_loss: 0.1296
# Epoch 104/200
# 129/129 - 0s - 62us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 105/200
# 2024-03-31 15:11:26.734838: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:11:26.737676: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 228ms/step - auc_2: 0.9934 - loss: 0.0903 - val_auc_2: 0.9911 - val_loss: 0.1092
# Epoch 106/200
# 129/129 - 0s - 59us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 107/200
# 2024-03-31 15:11:56.123684: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:11:56.126311: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9901 - loss: 0.1118 - val_auc_2: 0.9892 - val_loss: 0.1101
# Epoch 108/200
# 129/129 - 0s - 53us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 109/200
# 2024-03-31 15:12:25.447565: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:12:25.449814: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_2: 0.9934 - loss: 0.0890 - val_auc_2: 0.9843 - val_loss: 0.1323
# Epoch 110/200
# 129/129 - 0s - 62us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 111/200
# 2024-03-31 15:12:55.119258: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:12:55.122162: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_2: 0.9942 - loss: 0.0820 - val_auc_2: 0.9886 - val_loss: 0.1867
# Epoch 112/200
# 129/129 - 0s - 60us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 113/200
# 2024-03-31 15:13:23.903396: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:13:23.905787: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9943 - loss: 0.0844 - val_auc_2: 0.9877 - val_loss: 0.1352
# Epoch 114/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 115/200
# 2024-03-31 15:13:53.251037: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:13:53.253729: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_2: 0.9942 - loss: 0.0795 - val_auc_2: 0.9851 - val_loss: 0.1754
# Epoch 116/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 117/200
# 2024-03-31 15:14:22.086332: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:14:22.088970: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_2: 0.9942 - loss: 0.0785 - val_auc_2: 0.9892 - val_loss: 0.1147
# Epoch 118/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 119/200
# 2024-03-31 15:14:50.413555: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:14:50.416117: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9943 - loss: 0.0814 - val_auc_2: 0.9873 - val_loss: 0.1227
# Epoch 120/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 121/200
# 2024-03-31 15:15:19.648279: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:15:19.650835: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 226ms/step - auc_2: 0.9934 - loss: 0.0846 - val_auc_2: 0.9897 - val_loss: 0.1272
# Epoch 122/200
# 129/129 - 0s - 54us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 123/200
# 2024-03-31 15:15:48.843615: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:15:48.846160: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 224ms/step - auc_2: 0.9949 - loss: 0.0754 - val_auc_2: 0.9855 - val_loss: 0.1230
# Epoch 124/200
# 129/129 - 0s - 55us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 125/200
# 2024-03-31 15:16:17.776188: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:16:17.778595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_2: 0.9922 - loss: 0.0913 - val_auc_2: 0.9881 - val_loss: 0.1551
# Epoch 126/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 127/200
# 2024-03-31 15:16:46.537223: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:16:46.539784: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9943 - loss: 0.0778 - val_auc_2: 0.9888 - val_loss: 0.1385
# Epoch 128/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 129/200
# 2024-03-31 15:17:15.872893: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:17:15.875360: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_2: 0.9942 - loss: 0.0822 - val_auc_2: 0.9915 - val_loss: 0.1511
# Epoch 130/200
# 129/129 - 0s - 205us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 131/200
# 2024-03-31 15:17:44.609613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:17:44.620492: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_2: 0.9945 - loss: 0.0761 - val_auc_2: 0.9888 - val_loss: 0.1203
# Epoch 132/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 133/200
# 2024-03-31 15:18:14.940368: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:18:14.942867: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 228ms/step - auc_2: 0.9947 - loss: 0.0829 - val_auc_2: 0.9904 - val_loss: 0.1209
# Epoch 134/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 135/200
# 2024-03-31 15:18:44.332458: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:18:44.335071: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 28s - 220ms/step - auc_2: 0.9949 - loss: 0.0753 - val_auc_2: 0.9886 - val_loss: 0.1319
# Epoch 136/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 137/200
# 2024-03-31 15:19:12.779691: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:19:12.782284: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 223ms/step - auc_2: 0.9948 - loss: 0.0747 - val_auc_2: 0.9905 - val_loss: 0.1071
# Epoch 138/200
# 129/129 - 0s - 55us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 139/200
# 2024-03-31 15:19:41.552808: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:19:41.555379: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9956 - loss: 0.0718 - val_auc_2: 0.9895 - val_loss: 0.1136
# Epoch 140/200
# 129/129 - 0s - 54us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 141/200
# 2024-03-31 15:20:10.788447: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:20:10.790843: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 222ms/step - auc_2: 0.9941 - loss: 0.0758 - val_auc_2: 0.9883 - val_loss: 0.1313
# Epoch 142/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 143/200
# 2024-03-31 15:20:39.478354: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:20:39.481099: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_2: 0.9940 - loss: 0.0843 - val_auc_2: 0.9907 - val_loss: 0.1057
# Epoch 144/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 145/200
# 2024-03-31 15:21:08.569990: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:21:08.572609: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 238ms/step - auc_2: 0.9954 - loss: 0.0769 - val_auc_2: 0.9882 - val_loss: 0.1197
# Epoch 146/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 147/200
# 2024-03-31 15:21:39.249277: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:21:39.251812: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 238ms/step - auc_2: 0.9955 - loss: 0.0720 - val_auc_2: 0.9890 - val_loss: 0.1213
# Epoch 148/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 149/200
# 2024-03-31 15:22:09.922267: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:22:09.924886: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 231ms/step - auc_2: 0.9957 - loss: 0.0704 - val_auc_2: 0.9900 - val_loss: 0.1350
# Epoch 150/200
# 129/129 - 0s - 61us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 151/200
# 2024-03-31 15:22:39.703795: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:22:39.706554: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 233ms/step - auc_2: 0.9963 - loss: 0.0671 - val_auc_2: 0.9898 - val_loss: 0.1143
# Epoch 152/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 153/200
# 2024-03-31 15:23:09.771424: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:23:09.774289: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_2: 0.9955 - loss: 0.0764 - val_auc_2: 0.9918 - val_loss: 0.1046
# Epoch 154/200
# 129/129 - 0s - 75us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 155/200
# 2024-03-31 15:23:40.078888: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:23:40.081876: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_2: 0.9957 - loss: 0.0663 - val_auc_2: 0.9906 - val_loss: 0.1238
# Epoch 156/200
# 129/129 - 0s - 59us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 157/200
# 2024-03-31 15:24:09.785908: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:24:09.788698: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 232ms/step - auc_2: 0.9961 - loss: 0.0667 - val_auc_2: 0.9884 - val_loss: 0.1330
# Epoch 158/200
# 129/129 - 0s - 59us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 159/200
# 2024-03-31 15:24:39.763281: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:24:39.765959: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 234ms/step - auc_2: 0.9948 - loss: 0.0743 - val_auc_2: 0.9894 - val_loss: 0.1182
# Epoch 160/200
# 129/129 - 0s - 73us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 161/200
# 2024-03-31 15:25:09.936700: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:25:09.940546: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_2: 0.9960 - loss: 0.0667 - val_auc_2: 0.9915 - val_loss: 0.1136
# Epoch 162/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 163/200
# 2024-03-31 15:25:40.214363: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:25:40.216941: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 231ms/step - auc_2: 0.9942 - loss: 0.0743 - val_auc_2: 0.9857 - val_loss: 0.1266
# Epoch 164/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 165/200
# 2024-03-31 15:26:10.060278: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:26:10.062904: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_2: 0.9966 - loss: 0.0645 - val_auc_2: 0.9863 - val_loss: 0.1305
# Epoch 166/200
# 129/129 - 0s - 76us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 167/200
# 2024-03-31 15:26:40.444070: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:26:40.447216: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 243ms/step - auc_2: 0.9960 - loss: 0.0680 - val_auc_2: 0.9924 - val_loss: 0.1034
# Epoch 168/200
# 129/129 - 0s - 63us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 169/200
# 2024-03-31 15:27:11.842470: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:27:11.845383: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 235ms/step - auc_2: 0.9957 - loss: 0.0686 - val_auc_2: 0.9871 - val_loss: 0.1408
# Epoch 170/200
# 129/129 - 0s - 62us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 171/200
# 2024-03-31 15:27:42.107676: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:27:42.110418: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 240ms/step - auc_2: 0.9951 - loss: 0.0733 - val_auc_2: 0.9897 - val_loss: 0.1412
# Epoch 172/200
# 129/129 - 0s - 65us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 173/200
# 2024-03-31 15:28:13.122060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:28:13.125049: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 233ms/step - auc_2: 0.9959 - loss: 0.0673 - val_auc_2: 0.9907 - val_loss: 0.1308
# Epoch 174/200
# 129/129 - 0s - 56us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 175/200
# 2024-03-31 15:28:43.212810: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:28:43.215358: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 240ms/step - auc_2: 0.9958 - loss: 0.0673 - val_auc_2: 0.9898 - val_loss: 0.1113
# Epoch 176/200
# 129/129 - 0s - 74us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 177/200
# 2024-03-31 15:29:14.174636: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:29:14.178239: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 31s - 238ms/step - auc_2: 0.9960 - loss: 0.0664 - val_auc_2: 0.9921 - val_loss: 0.1222
# Epoch 178/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 179/200
# 2024-03-31 15:29:44.947167: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:29:44.949703: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 225ms/step - auc_2: 0.9962 - loss: 0.0694 - val_auc_2: 0.9918 - val_loss: 0.0980
# Epoch 180/200
# 129/129 - 0s - 60us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 181/200
# 2024-03-31 15:30:13.972379: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:30:13.975095: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 228ms/step - auc_2: 0.9951 - loss: 0.0680 - val_auc_2: 0.9880 - val_loss: 0.1366
# Epoch 182/200
# 129/129 - 0s - 55us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 183/200
# 2024-03-31 15:30:43.344250: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:30:43.346838: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 229ms/step - auc_2: 0.9964 - loss: 0.0667 - val_auc_2: 0.9924 - val_loss: 0.1051
# Epoch 184/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 185/200
# 2024-03-31 15:31:12.933498: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:31:12.936163: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 227ms/step - auc_2: 0.9957 - loss: 0.0689 - val_auc_2: 0.9888 - val_loss: 0.1102
# Epoch 186/200
# 129/129 - 0s - 59us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 187/200
# 2024-03-31 15:31:42.217584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:31:42.220199: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 29s - 228ms/step - auc_2: 0.9964 - loss: 0.0634 - val_auc_2: 0.9873 - val_loss: 0.1330
# Epoch 188/200
# 129/129 - 0s - 54us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 189/200
# 2024-03-31 15:32:11.640695: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:32:11.643144: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_2: 0.9963 - loss: 0.0645 - val_auc_2: 0.9902 - val_loss: 0.1197
# Epoch 190/200
# 129/129 - 0s - 53us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 191/200
# 2024-03-31 15:32:41.300391: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:32:41.302814: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 232ms/step - auc_2: 0.9976 - loss: 0.0559 - val_auc_2: 0.9904 - val_loss: 0.1306
# Epoch 192/200
# 129/129 - 0s - 70us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 193/200
# 2024-03-31 15:33:11.275836: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:33:11.279029: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 231ms/step - auc_2: 0.9975 - loss: 0.0550 - val_auc_2: 0.9871 - val_loss: 0.1348
# Epoch 194/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 195/200
# 2024-03-31 15:33:41.112014: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:33:41.114684: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 231ms/step - auc_2: 0.9957 - loss: 0.0601 - val_auc_2: 0.9917 - val_loss: 0.1102
# Epoch 196/200
# 129/129 - 0s - 53us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 197/200
# 2024-03-31 15:34:10.911380: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:34:10.913805: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_2: 0.9973 - loss: 0.0574 - val_auc_2: 0.9902 - val_loss: 0.1117
# Epoch 198/200
# 129/129 - 0s - 58us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 199/200
# 2024-03-31 15:34:40.629509: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:34:40.632114: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 129/129 - 30s - 230ms/step - auc_2: 0.9963 - loss: 0.0592 - val_auc_2: 0.9895 - val_loss: 0.1113
# Epoch 200/200
# 129/129 - 0s - 57us/step - auc_2: 0.0000e+00 - loss: 0.0000e+00 - val_auc_2: 0.0000e+00 - val_loss: 0.0000e+00
# 2024-03-31 15:35:10.282047: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-03-31 15:35:10.284736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step
# [Summary Statistics]
# Accuracy = 92.12% | Precision = 92.55% | Recall = 97.03% | Specificity = 78.81% | F1 Score = 94.74%
